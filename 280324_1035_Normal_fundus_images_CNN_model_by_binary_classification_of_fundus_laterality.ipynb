# %% [markdown]
# <a href="https://colab.research.google.com/github/drskprabhakar/Axial-Length-Prediction-ML-Regression-mode/blob/main/280324_1035_Normal_fundus_images_CNN_model_by_binary_classification_of_fundus_laterality.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
os.listdir('/content/drive/MyDrive/Normal Fundus Images/split')
# Out:
# ['train', 'val', 'test']

# %%
os.listdir('/content/drive/MyDrive/Normal Fundus Images/split/train'),
os.listdir('/content/drive/MyDrive/Normal Fundus Images/split/val'),
os.listdir('/content/drive/MyDrive/Normal Fundus Images/split/test')
# Out:
# ['left eye fundus', 'right eye fundus']

# %%
from keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator()

trainimages = datagen.flow_from_directory('/content/drive/MyDrive/Normal Fundus Images/split/train',
                                          target_size = (64,64),
                                          class_mode='binary')
valimages = datagen.flow_from_directory('/content/drive/MyDrive/Normal Fundus Images/split/val',
                                          target_size = (64,64),
                                          class_mode='binary')
testimages = datagen.flow_from_directory('/content/drive/MyDrive/Normal Fundus Images/split/test',
                                          target_size = (64,64),
                                          class_mode='binary')
# Out:
# Found 846 images belonging to 2 classes.
# Found 103 images belonging to 2 classes.
# Found 84 images belonging to 2 classes.

# %%
from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Flatten,Dense

model = Sequential([Conv2D(32,(3,3), activation = 'relu', input_shape = (64,64,3)),
                    MaxPooling2D(2,2),

                    Conv2D(32,(3,3), activation='relu'),
                    MaxPooling2D(2,2),
                    Conv2D(64,(3,3), activation='relu'),
                    MaxPooling2D(2,2),

                    Flatten(),
                    Dense(128, activation = 'relu'),
                    Dense(1, activation = 'sigmoid')])

model.compile(optimizer='adam',
              loss = 'binary_crossentropy',
              metrics = 'accuracy')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 62, 62, 32)        896
#
#  max_pooling2d (MaxPooling2  (None, 31, 31, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 29, 29, 32)        9248
#
#  max_pooling2d_1 (MaxPoolin  (None, 14, 14, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 64)        18496
#
#  max_pooling2d_2 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 128)               295040
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 323809 (1.24 MB)
# Trainable params: 323809 (1.24 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(trainimages,
          batch_size= 32,
          epochs =50,
          validation_data=valimages)
model.save('binary_cnnmodel.keras')
# Out:
# Epoch 1/50
# 27/27 [==============================] - 280s 10s/step - loss: 2.8804 - accuracy: 0.7872 - val_loss: 0.1309 - val_accuracy: 0.9612
# Epoch 2/50
# 27/27 [==============================] - 8s 284ms/step - loss: 0.1251 - accuracy: 0.9669 - val_loss: 0.0926 - val_accuracy: 0.9515
# Epoch 3/50
# 27/27 [==============================] - 7s 256ms/step - loss: 0.0844 - accuracy: 0.9823 - val_loss: 0.0759 - val_accuracy: 0.9709
# Epoch 4/50
# 27/27 [==============================] - 7s 273ms/step - loss: 0.0846 - accuracy: 0.9787 - val_loss: 0.1286 - val_accuracy: 0.9223
# Epoch 5/50
# 27/27 [==============================] - 7s 263ms/step - loss: 0.0673 - accuracy: 0.9823 - val_loss: 0.0771 - val_accuracy: 0.9806
# Epoch 6/50
# 27/27 [==============================] - 7s 253ms/step - loss: 0.0645 - accuracy: 0.9858 - val_loss: 0.0594 - val_accuracy: 0.9903
# Epoch 7/50
# 27/27 [==============================] - 8s 292ms/step - loss: 0.0523 - accuracy: 0.9870 - val_loss: 0.0775 - val_accuracy: 0.9806
# Epoch 8/50
# 27/27 [==============================] - 8s 287ms/step - loss: 0.0456 - accuracy: 0.9905 - val_loss: 0.0727 - val_accuracy: 0.9806
# Epoch 9/50
# 27/27 [==============================] - 7s 252ms/step - loss: 0.0406 - accuracy: 0.9917 - val_loss: 0.0743 - val_accuracy: 0.9806
# Epoch 10/50
# 27/27 [==============================] - 8s 278ms/step - loss: 0.0323 - accuracy: 0.9976 - val_loss: 0.0912 - val_accuracy: 0.9709
# Epoch 11/50
# 27/27 [==============================] - 7s 255ms/step - loss: 0.0342 - accuracy: 0.9941 - val_loss: 0.0743 - val_accuracy: 0.9709
# Epoch 12/50
# 27/27 [==============================] - 7s 248ms/step - loss: 0.0274 - accuracy: 0.9953 - val_loss: 0.0854 - val_accuracy: 0.9806
# Epoch 13/50
# 27/27 [==============================] - 7s 246ms/step - loss: 0.0346 - accuracy: 0.9941 - val_loss: 0.0782 - val_accuracy: 0.9806
# Epoch 14/50
# 27/27 [==============================] - 7s 264ms/step - loss: 0.0344 - accuracy: 0.9953 - val_loss: 0.0796 - val_accuracy: 0.9806
# Epoch 15/50
# 27/27 [==============================] - 7s 264ms/step - loss: 0.0257 - accuracy: 0.9941 - val_loss: 0.0998 - val_accuracy: 0.9709
# Epoch 16/50
# 27/27 [==============================] - 7s 244ms/step - loss: 0.0262 - accuracy: 0.9976 - val_loss: 0.0835 - val_accuracy: 0.9806
# Epoch 17/50
# 27/27 [==============================] - 7s 275ms/step - loss: 0.1018 - accuracy: 0.9610 - val_loss: 0.2680 - val_accuracy: 0.9126
# Epoch 18/50
# 27/27 [==============================] - 8s 282ms/step - loss: 0.0874 - accuracy: 0.9764 - val_loss: 0.1199 - val_accuracy: 0.9515
# Epoch 19/50
# 27/27 [==============================] - 7s 250ms/step - loss: 0.0549 - accuracy: 0.9905 - val_loss: 0.0818 - val_accuracy: 0.9709
# Epoch 20/50
# 27/27 [==============================] - 7s 276ms/step - loss: 0.0695 - accuracy: 0.9811 - val_loss: 0.0549 - val_accuracy: 0.9806
# Epoch 21/50
# 27/27 [==============================] - 6s 240ms/step - loss: 0.0827 - accuracy: 0.9846 - val_loss: 0.0715 - val_accuracy: 0.9709
# Epoch 22/50
# 27/27 [==============================] - 7s 273ms/step - loss: 0.0547 - accuracy: 0.9846 - val_loss: 0.1565 - val_accuracy: 0.9320
# Epoch 23/50
# 27/27 [==============================] - 7s 247ms/step - loss: 0.0336 - accuracy: 0.9941 - val_loss: 0.0575 - val_accuracy: 0.9806
# Epoch 24/50
# 27/27 [==============================] - 7s 264ms/step - loss: 0.0342 - accuracy: 0.9941 - val_loss: 0.0769 - val_accuracy: 0.9806
# Epoch 25/50
# 27/27 [==============================] - 7s 265ms/step - loss: 0.0368 - accuracy: 0.9953 - val_loss: 0.0772 - val_accuracy: 0.9806
# Epoch 26/50
# 27/27 [==============================] - 6s 238ms/step - loss: 0.0252 - accuracy: 0.9965 - val_loss: 0.0482 - val_accuracy: 0.9903
# Epoch 27/50
# 27/27 [==============================] - 7s 274ms/step - loss: 0.0226 - accuracy: 0.9965 - val_loss: 0.0608 - val_accuracy: 0.9903
# Epoch 28/50
# 27/27 [==============================] - 7s 249ms/step - loss: 0.0182 - accuracy: 0.9965 - val_loss: 0.0521 - val_accuracy: 0.9903
# Epoch 29/50
# 27/27 [==============================] - 7s 271ms/step - loss: 0.0237 - accuracy: 0.9965 - val_loss: 0.0818 - val_accuracy: 0.9612
# Epoch 30/50
# 27/27 [==============================] - 7s 275ms/step - loss: 0.0219 - accuracy: 0.9965 - val_loss: 0.0717 - val_accuracy: 0.9903
# Epoch 31/50
# 27/27 [==============================] - 7s 244ms/step - loss: 0.0167 - accuracy: 0.9976 - val_loss: 0.1156 - val_accuracy: 0.9515
# Epoch 32/50
# 27/27 [==============================] - 7s 249ms/step - loss: 0.0199 - accuracy: 0.9965 - val_loss: 0.0606 - val_accuracy: 0.9903
# Epoch 33/50
# 27/27 [==============================] - 7s 275ms/step - loss: 0.0126 - accuracy: 0.9976 - val_loss: 0.0527 - val_accuracy: 0.9903
# Epoch 34/50
# 27/27 [==============================] - 6s 244ms/step - loss: 0.0140 - accuracy: 0.9976 - val_loss: 0.0915 - val_accuracy: 0.9709
# Epoch 35/50
# 27/27 [==============================] - 7s 261ms/step - loss: 0.0161 - accuracy: 0.9965 - val_loss: 0.0552 - val_accuracy: 0.9806
# Epoch 36/50
# 27/27 [==============================] - 7s 272ms/step - loss: 0.0122 - accuracy: 0.9965 - val_loss: 0.1191 - val_accuracy: 0.9709
# Epoch 37/50
# 27/27 [==============================] - 7s 249ms/step - loss: 0.0153 - accuracy: 0.9976 - val_loss: 0.0654 - val_accuracy: 0.9709
# Epoch 38/50
# 27/27 [==============================] - 7s 274ms/step - loss: 0.0161 - accuracy: 0.9976 - val_loss: 0.0544 - val_accuracy: 0.9903
# Epoch 39/50
# 27/27 [==============================] - 7s 248ms/step - loss: 0.0154 - accuracy: 0.9965 - val_loss: 0.0754 - val_accuracy: 0.9903
# Epoch 40/50
# 27/27 [==============================] - 7s 246ms/step - loss: 0.0149 - accuracy: 0.9965 - val_loss: 0.0685 - val_accuracy: 0.9806
# Epoch 41/50
# 27/27 [==============================] - 7s 271ms/step - loss: 0.0124 - accuracy: 0.9953 - val_loss: 0.1815 - val_accuracy: 0.9417
# Epoch 42/50
# 27/27 [==============================] - 7s 266ms/step - loss: 0.0177 - accuracy: 0.9941 - val_loss: 0.0441 - val_accuracy: 0.9806
# Epoch 43/50
# 27/27 [==============================] - 6s 235ms/step - loss: 0.0134 - accuracy: 0.9953 - val_loss: 0.0922 - val_accuracy: 0.9709
# Epoch 44/50
# 27/27 [==============================] - 7s 250ms/step - loss: 0.0219 - accuracy: 0.9929 - val_loss: 0.0466 - val_accuracy: 0.9903
# Epoch 45/50
# 27/27 [==============================] - 7s 271ms/step - loss: 0.0111 - accuracy: 0.9976 - val_loss: 0.0705 - val_accuracy: 0.9903
# Epoch 46/50
# 27/27 [==============================] - 7s 259ms/step - loss: 0.0147 - accuracy: 0.9941 - val_loss: 0.0633 - val_accuracy: 0.9903
# Epoch 47/50
# 27/27 [==============================] - 7s 242ms/step - loss: 0.0079 - accuracy: 0.9976 - val_loss: 0.1053 - val_accuracy: 0.9709
# Epoch 48/50
# 27/27 [==============================] - 7s 241ms/step - loss: 0.0106 - accuracy: 0.9976 - val_loss: 0.0885 - val_accuracy: 0.9903
# Epoch 49/50
# 27/27 [==============================] - 7s 271ms/step - loss: 0.0395 - accuracy: 0.9905 - val_loss: 0.4527 - val_accuracy: 0.8641
# Epoch 50/50
# 27/27 [==============================] - 7s 245ms/step - loss: 0.0329 - accuracy: 0.9905 - val_loss: 0.0593 - val_accuracy: 0.9709

# %%
y_true = testimages.classes

# %%
testimages.class_indices
# Out:
# {'left eye fundus': 0, 'right eye fundus': 1}

# %%
y_pred=model.predict(testimages)
# Out:
# 3/3 [==============================] - 27s 14s/step

# %%
y_pred[y_pred<=0.5]=0
y_pred[y_pred>0.5]=1

# %%
from sklearn import metrics
metrics.confusion_matrix(y_true,y_pred)
# Out:
# array([[27, 15],
#        [17, 25]])

# %%
metrics.ConfusionMatrixDisplay.from_predictions(y_true,y_pred)

# %%
print(metrics.classification_report(y_true,y_pred,
                                    target_names=['left eye fundus',
                                                  'right eye fundus']))
# Out:
#                   precision    recall  f1-score   support
#
#  left eye fundus       0.61      0.64      0.63        42
# right eye fundus       0.62      0.60      0.61        42
#
#         accuracy                           0.62        84
#        macro avg       0.62      0.62      0.62        84
#     weighted avg       0.62      0.62      0.62        84

# %%
metrics.RocCurveDisplay.from_predictions(y_true,y_pred)

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model

# Load the trained CNN model
model = load_model('/content/binary_cnnmodel.keras')  # Provide the path to your trained model file

# Define a function to predict unknown images
def predict_unknown_image(image_path):
    img = image.load_img(image_path, target_size=(64,64))  # Assuming images are resized to 150x150
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)  # Expand dimensions to match batch size
    img_array /= 255.0  # Normalize pixel values

    prediction = model.predict(img_array)
    if prediction[0][0] > 0.5:
        return "Right eye fundus"  # Example class names, modify as per your binary classes
    else:
        return "Left eye fundus"

# Example usage:
unknown_image_path = "/content/drive/MyDrive/Normal Fundus Images/left eye fundus/1034_left.jpg"  # Provide the path to the unknown image
prediction = predict_unknown_image(unknown_image_path)
print("Prediction:", prediction)

import matplotlib.pyplot as plt
testimage1 = image.load_img('/content/drive/MyDrive/Normal Fundus Images/left eye fundus/1034_left.jpg')
plt.imshow(testimage1)
# Out:
# 1/1 [==============================] - 0s 324ms/step
# Prediction: Left eye fundus

# %%
# Example usage:
unknown_image_path = "/content/drive/MyDrive/Normal Fundus Images/right eye fundus/1034_right.jpg"  # Provide the path to the unknown image
prediction = predict_unknown_image(unknown_image_path)
print("Prediction:", prediction)

testimage1 = image.load_img('/content/drive/MyDrive/Normal Fundus Images/right eye fundus/1034_right.jpg')
plt.imshow(testimage1)
# Out:
# 1/1 [==============================] - 0s 21ms/step
# Prediction: Right eye fundus

# %%
unknown_image_path = "/content/drive/MyDrive/1200px-Fundus_photograph_of_normal_right_eye.jpg"  # Provide the path to the unknown image
prediction = predict_unknown_image(unknown_image_path)
print("Prediction:", prediction)

testimage1 = image.load_img('/content/drive/MyDrive/1200px-Fundus_photograph_of_normal_right_eye.jpg')
plt.imshow(testimage1)
# Out:
# 1/1 [==============================] - 0s 17ms/step
# Prediction: Left eye fundus
