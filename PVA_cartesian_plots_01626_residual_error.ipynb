# %% [markdown]
# <a href="https://colab.research.google.com/github/drskprabhakar/AI-ML-DL-colab-notebooks-coding-models/blob/main/PVA_cartesian_plots_01626_residual_error.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
sheets = pd.ExcelFile('/content/drive/MyDrive/AK and AR 1wk, 6wk and 3 months 011225.xlsx')
sheets.sheet_names
# Out:
# ['raw data', 'data 1wk, 6wk and 3 months', 'sorted data']

# %%
sorted_data
# Out:
#      Age Gender   PreopR1  PreopR2  PreopA1     Sph1wk  Cyl1wk  Axis1wk  \
# 0     54       F    46.50    47.25      155       0.25   -1.50    115.0
# 1     63       F    46.75    48.00       80       0.75   -2.25     80.0
# 2     78       F    44.00    44.25       20  NO CENTER     NaN      NaN
# 3     71       F    45.25    45.75      120      -0.75   -1.00    160.0
# 4     89       M    45.50    47.00       80       0.25    2.00     75.0
# ..   ...     ...      ...      ...      ...        ...     ...      ...
# 167   54       M    45.00    46.25      165      -2.75   -3.00     75.0
# 168   57       M    41.00    42.50       85  NO CENTER     NaN      NaN
# 169   72       M    44.75    45.75       75  NO CENTER     NaN      NaN
# 170   74       M    44.75    45.25      170  NO CENTER     NaN      NaN
# 171   52       M    44.75    44.75      180      -3.25   -3.00     40.0
#
#     Sph6wk   Cyl6wk  Axis6wk  Sph3mth  Cyl3mth  Axis3mth
# ...
