# %% [markdown]
# <a href="https://colab.research.google.com/github/drskprabhakar/AI-ML-DL-colab-notebooks-coding-models/blob/main/Kalyani_3_follow_ups_arak11825.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df = pd.read_excel('/content/drive/MyDrive/Kalyani 3 followups AR.xlsx')
df
# Out:
#      AGE  SEX_numeric     KH     KV   AX V/A PRE OP  numerator  denominator  \
# 0     54            1  46.50  47.25  155       6\24        6.0           24
# 1     63            1  46.75  48.00   80        HM         0.3           60
# 2     71            1  45.25  45.75  120      CF@1M        1.0           60
# 3     89            0  45.50  47.00   80       6\36        6.0           36
# 4     59            1  42.50  43.50   75       6\60        6.0           60
# ..   ...          ...    ...    ...  ...        ...        ...          ...
# 126   66            1  43.25  44.00   60       6\60        6.0           60
# 127   57            1  47.00  48.25  165       6\24        6.0           24
# 128   52            1  42.00  42.50  110    CF @ 1M        1.0           60
# 129   54            0  45.00  46.25  165       6\36        6.0           36
# 130   52            0  44.75  44.75  180       6\36        6.0           36
#
#      preop logMAR POD 1 DAY V/A  numerator.1  denominator.1  day1 logMAR  \
# 0        0.602060          6\12            6             12     0.301030
# 1        2.301030          6\18            6             18     0.477121
# 2        1.778151          6\18            6             18     0.477121
# 3        0.778151          6\12            6             12     0.301030
# 4        1.000000          6\24            6             24     0.602060
# ..            ...           ...          ...            ...          ...
# 126      1.000000          6\24            6             24     0.602060
# 127      0.602060           6\9            6              9     0.176091
# 128      1.778151          6\12            6             12     0.301030
# 129      0.778151          6\18            6             18     0.477121
# 130      0.778151          6\24            6             24     0.602060
#
#       SPH   CYL  AXIS
# 0    0.25 -1.50   115
# 1    0.75 -2.25    80
# 2   -0.75 -1.00   160
# 3    0.25  2.00    75
# 4    2.00 -2.00    90
# ..    ...   ...   ...
# 126 -2.75 -3.00    60
# 127  1.25 -1.75    15
# 128 -0.75 -1.25    95
# 129 -2.75 -3.00    75
# 130 -3.25 -3.00    40
#
# [131 rows x 16 columns]

# %%
sheets = pd.ExcelFile('/content/drive/MyDrive/Kalyani 3 followups AR.xlsx')
sheets.sheet_names
# Out:
# ['day1AR', '6weeksAR', '3monthsAR']

# %%
day1 = sheets.parse('day1AR')
wk6 = sheets.parse('6weeksAR')
mth3 = sheets.parse('3monthsAR')

# %%
day1.head()
# Out:
#    AGE  SEX_numeric     KH     KV   AX V/A PRE OP  numerator  denominator  \
# 0   54            1  46.50  47.25  155       6\24        6.0           24
# 1   63            1  46.75  48.00   80        HM         0.3           60
# 2   71            1  45.25  45.75  120      CF@1M        1.0           60
# 3   89            0  45.50  47.00   80       6\36        6.0           36
# 4   59            1  42.50  43.50   75       6\60        6.0           60
#
#    preop logMAR POD 1 DAY V/A  numerator.1  denominator.1  day1 logMAR   SPH  \
# 0      0.602060          6\12            6             12     0.301030  0.25
# 1      2.301030          6\18            6             18     0.477121  0.75
# 2      1.778151          6\18            6             18     0.477121 -0.75
# 3      0.778151          6\12            6             12     0.301030  0.25
# 4      1.000000          6\24            6             24     0.602060  2.00
#
#     CYL  AXIS
# 0 -1.50   115
# 1 -2.25    80
# 2 -1.00   160
# 3  2.00    75
# 4 -2.00    90

# %%
day1.shape,day1.columns
# Out:
# ((131, 16),
#  Index(['AGE', 'SEX_numeric', 'KH', 'KV', 'AX', 'V/A PRE OP', 'numerator',
#         'denominator', 'preop logMAR', 'POD 1 DAY V/A', 'numerator.1',
#         'denominator.1', 'day1 logMAR', 'SPH', 'CYL', 'AXIS'],
#        dtype='object'))

# %%
day1AR = day1[['AGE', 'SEX_numeric', 'KH', 'KV', 'AX', 'preop logMAR', 'day1 logMAR', 'SPH', 'CYL', 'AXIS']]
day1AR
# Out:
#      AGE  SEX_numeric     KH     KV   AX  preop logMAR  day1 logMAR   SPH  \
# 0     54            1  46.50  47.25  155      0.602060     0.301030  0.25
# 1     63            1  46.75  48.00   80      2.301030     0.477121  0.75
# 2     71            1  45.25  45.75  120      1.778151     0.477121 -0.75
# 3     89            0  45.50  47.00   80      0.778151     0.301030  0.25
# 4     59            1  42.50  43.50   75      1.000000     0.602060  2.00
# ..   ...          ...    ...    ...  ...           ...          ...   ...
# 126   66            1  43.25  44.00   60      1.000000     0.602060 -2.75
# 127   57            1  47.00  48.25  165      0.602060     0.176091  1.25
# 128   52            1  42.00  42.50  110      1.778151     0.301030 -0.75
# 129   54            0  45.00  46.25  165      0.778151     0.477121 -2.75
# 130   52            0  44.75  44.75  180      0.778151     0.602060 -3.25
#
#       CYL  AXIS
# 0   -1.50   115
# 1   -2.25    80
# 2   -1.00   160
# 3    2.00    75
# 4   -2.00    90
# ..    ...   ...
# 126 -3.00    60
# 127 -1.75    15
# 128 -1.25    95
# 129 -3.00    75
# 130 -3.00    40
#
# [131 rows x 10 columns]

# %%
day1AR.isnull().sum()
# Out:
# AGE             0
# SEX_numeric     0
# KH              0
# KV              0
# AX              0
# preop logMAR    0
# day1 logMAR     0
# SPH             0
# CYL             0
# AXIS            0
# dtype: int64

# %%
day1AR.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AGE           131 non-null    int64
#  1   SEX_numeric   131 non-null    int64
#  2   KH            131 non-null    float64
#  3   KV            131 non-null    float64
#  4   AX            131 non-null    int64
#  5   preop logMAR  131 non-null    float64
#  6   day1 logMAR   131 non-null    float64
#  7   SPH           131 non-null    float64
#  8   CYL           131 non-null    float64
#  9   AXIS          131 non-null    int64
# dtypes: float64(6), int64(4)
# memory usage: 10.4 KB

# %%
day1AR.shape, day1AR.columns
# Out:
# ((131, 10),
#  Index(['AGE', 'SEX_numeric', 'KH', 'KV', 'AX', 'preop logMAR', 'day1 logMAR',
#         'SPH', 'CYL', 'AXIS'],
#        dtype='object'))

# %%
day1AR['AGE'].describe()
# Out:
# count    131.000000
# mean      63.839695
# std        9.656259
# min       38.000000
# 25%       56.000000
# 50%       65.000000
# 75%       71.000000
# max       93.000000
# Name: AGE, dtype: float64

# %%
day1AR['AGE'].hist()
# Out:
# <Axes: >

# %%
day1AR['AGE'].plot.box()
# Out:
# <Axes: >

# %%
display(day1AR.groupby('SEX_numeric')['AGE'].describe())
# Out:
#              count       mean        std   min   25%   50%   75%   max
# SEX_numeric
# 0             49.0  63.714286  10.366211  38.0  56.0  65.0  69.0  89.0
# 1             82.0  63.914634   9.271224  46.0  57.0  63.5  71.0  93.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(data=day1AR, x='AGE', hue='SEX_numeric', multiple='dodge', kde=True)
plt.title('Age Distribution by Gender')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.boxplot(data=day1AR, x='SEX_numeric', y='AGE')
plt.title('Age Distribution by Gender')
plt.xlabel('Males(0) or Females (1)')
plt.ylabel('Age')
plt.show()

# %%
from scipy.stats import ttest_ind

# Separate the data into two groups based on 'SEX_numeric'
group0 = day1AR[day1AR['SEX_numeric'] == 0]['AGE']
group1 = day1AR[day1AR['SEX_numeric'] == 1]['AGE']

# Perform independent samples t-test
ttest_statistic, p_value = ttest_ind(group0, group1)

print(f"T-test statistic: {ttest_statistic}")
print(f"P-value: {p_value}")
# Out:
# T-test statistic: -0.11446997854341573
# P-value: 0.9090432196156961

# %%
day1AR.corr()
# Out:
#                    AGE  SEX_numeric        KH        KV        AX  \
# AGE           1.000000     0.010078 -0.041116 -0.002384 -0.210272
# SEX_numeric   0.010078     1.000000  0.187422  0.162903 -0.067337
# KH           -0.041116     0.187422  1.000000  0.942591  0.064784
# KV           -0.002384     0.162903  0.942591  1.000000  0.042055
# AX           -0.210272    -0.067337  0.064784  0.042055  1.000000
# preop logMAR -0.079381     0.016944 -0.099052 -0.051368 -0.171008
# day1 logMAR   0.203048    -0.093151 -0.059560 -0.068860 -0.110551
# SPH           0.132260     0.074012  0.034477  0.017701 -0.018233
# CYL          -0.082297    -0.035206 -0.069586 -0.057384 -0.057189
# AXIS          0.075103     0.113769  0.103171  0.081597  0.020087
#
#               preop logMAR  day1 logMAR       SPH       CYL      AXIS
# AGE              -0.079381     0.203048  0.132260 -0.082297  0.075103
# SEX_numeric       0.016944    -0.093151  0.074012 -0.035206  0.113769
# KH               -0.099052    -0.059560  0.034477 -0.069586  0.103171
# KV               -0.051368    -0.068860  0.017701 -0.057384  0.081597
# AX               -0.171008    -0.110551 -0.018233 -0.057189  0.020087
# preop logMAR      1.000000     0.298275 -0.067073  0.062275  0.072838
# day1 logMAR       0.298275     1.000000 -0.069284 -0.123313 -0.060967
# SPH              -0.067073    -0.069284  1.000000  0.055372 -0.006477
# CYL               0.062275    -0.123313  0.055372  1.000000  0.084981
# AXIS              0.072838    -0.060967 -0.006477  0.084981  1.000000

# %%
# Create a new column 'Classification' in day1AR
day1AR['Classification'] = day1AR.apply(
    lambda row: 'compound Myopic Astigmatism' if row['SPH'] < 0 and row['CYL'] < 0 else
                'compound Hyperopic Astigmatism' if row['SPH'] > 0 and row['CYL'] > 0 else

                'simple myopic astigmatism' if row['SPH'] == 0 and row['CYL'] < 0 else
                'simple hyperopic astigmatism' if row['SPH'] == 0 and row['CYL'] > 0 else
                'mixed astigmatism',
    axis=1
)

# View result
print(day1AR[['SPH', 'CYL', 'AXIS','Classification']])
# Out:
#       SPH   CYL  AXIS                  Classification
# 0    0.25 -1.50   115               mixed astigmatism
# 1    0.75 -2.25    80               mixed astigmatism
# 2   -0.75 -1.00   160     compound Myopic Astigmatism
# 3    0.25  2.00    75  compound Hyperopic Astigmatism
# 4    2.00 -2.00    90               mixed astigmatism
# ..    ...   ...   ...                             ...
# 126 -2.75 -3.00    60     compound Myopic Astigmatism
# 127  1.25 -1.75    15               mixed astigmatism
# 128 -0.75 -1.25    95     compound Myopic Astigmatism
# 129 -2.75 -3.00    75     compound Myopic Astigmatism
# 130 -3.25 -3.00    40     compound Myopic Astigmatism
#
# [131 rows x 4 columns]
# /tmp/ipython-input-2059324047.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day1AR['Classification'] = day1AR.apply(

# %%
# Frequency of each refractive error type
classification_counts = day1AR['Classification'].value_counts()
print(classification_counts)
# Out:
# Classification
# mixed astigmatism                 62
# compound Myopic Astigmatism       48
# compound Hyperopic Astigmatism    14
# simple myopic astigmatism          6
# simple hyperopic astigmatism       1
# Name: count, dtype: int64

# %%
# Descriptive stats by classification group
grouped_stats = day1AR.groupby('Classification')[['SPH', 'CYL', 'AXIS']].describe()
print(grouped_stats)
# Out:
#                                  SPH                                       \
#                                count      mean       std   min   25%  50%
# Classification
# compound Hyperopic Astigmatism  14.0  1.214286  0.908598  0.25  0.75  1.0
# compound Myopic Astigmatism     48.0 -1.250000  0.862949 -3.25 -1.75 -1.0
# mixed astigmatism               62.0  1.096774  0.888629 -2.25  0.50  1.0
# simple hyperopic astigmatism     1.0  0.000000       NaN  0.00  0.00  0.0
# simple myopic astigmatism        6.0  0.000000  0.000000  0.00  0.00  0.0
#
#                                                CYL            ...              \
#                                    75%   max count      mean  ...   75%   max
# Classification                                                ...
# compound Hyperopic Astigmatism  1.6250  3.50  14.0  1.928571  ...  3.00  3.75
# compound Myopic Astigmatism    -0.6875 -0.25  48.0 -1.848958  ... -1.00 -0.50
# mixed astigmatism               1.7500  3.00  62.0 -2.080645  ... -1.25  3.75
# simple hyperopic astigmatism    0.0000  0.00   1.0  1.000000  ...  1.00  1.00
# simple myopic astigmatism       0.0000  0.00   6.0 -1.125000  ... -1.00 -0.25
#
#                                 AXIS                                      \
#                                count        mean        std   min    25%
# Classification
# compound Hyperopic Astigmatism  14.0   97.000000  42.197339  18.0  76.25
# compound Myopic Astigmatism     48.0   93.125000  43.924803   5.0  65.00
# mixed astigmatism               62.0   82.338710  29.249040  10.0  75.00
# simple hyperopic astigmatism     1.0   90.000000        NaN  90.0  90.00
# simple myopic astigmatism        6.0  111.666667  40.824829  50.0  90.00
#
#
#                                   50%     75%    max
# Classification
# compound Hyperopic Astigmatism   95.0  112.50  175.0
# compound Myopic Astigmatism      95.0  116.25  180.0
# mixed astigmatism                82.5   90.00  175.0
# simple hyperopic astigmatism     90.0   90.00   90.0
# simple myopic astigmatism       120.0  131.25  165.0
#
# [5 rows x 24 columns]

# %%
import matplotlib.pyplot as plt

day1AR['Classification'].value_counts().plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Distribution of Refractive Error Types')
plt.xlabel('Classification')
plt.ylabel('Count')
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# SPH boxplot
sns.boxplot(x='Classification', y='SPH', data=day1AR)
plt.title('SPH Distribution by Classification')
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# CYL boxplot
sns.boxplot(x='Classification', y='CYL', data=day1AR)
plt.title('CYL Distribution by Classification')
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# AXIS boxplot
sns.boxplot(x='Classification', y='AXIS', data=day1AR)
plt.title('AXIS Distribution by Classification')
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %%
# Separate Astigmatisms
mixed_df = day1AR[day1AR['Classification'] == 'mixed astigmatism']
C_myopic_df = day1AR[day1AR['Classification']=='compound Myopic Astigmatism']
C_hyperopic_df=day1AR[day1AR['Classification']=='compound Hyperopic Astigmatism']
S_myopic_df = day1AR[day1AR['Classification'] == 'simple myopic astigmatism']
S_hyperopic_df = day1AR[day1AR['Classification'] == 'simple hyperopic astigmatism']

# %%
mixed_df.shape, C_myopic_df.shape, C_hyperopic_df.shape, S_myopic_df.shape, S_hyperopic_df.shape
# Out:
# ((62, 11), (48, 11), (14, 11), (6, 11), (1, 11))

# %% [markdown]
# ## Mixed astigmatism analysis

# %%
mixed_df.columns
# Out:
# Index(['AGE', 'SEX_numeric', 'KH', 'KV', 'AX', 'preop logMAR', 'day1 logMAR',
#        'SPH', 'CYL', 'AXIS', 'Classification'],
#       dtype='object')

# %%
mixed_df[['AGE', 'SEX_numeric', 'KH', 'KV', 'AX','preop logMAR', 'day1 logMAR','SPH', 'CYL', 'AXIS']].describe()
# Out:
#              AGE  SEX_numeric         KH         KV          AX  preop logMAR  \
# count  62.000000    62.000000  62.000000  62.000000   62.000000     62.000000
# mean   63.677419     0.693548  44.544355  45.298387  108.306452      1.306947
# std    10.306411     0.464783   1.384579   1.449165   49.306199      0.601023
# min    38.000000     0.000000  40.750000  41.750000    5.000000      0.301030
# 25%    56.000000     0.000000  43.500000  44.500000   75.000000      0.778151
# 50%    63.500000     1.000000  44.750000  45.250000   90.000000      1.301030
# 75%    71.000000     1.000000  45.500000  46.000000  158.750000      1.778151
# max    93.000000     1.000000  47.500000  49.000000  180.000000      2.778151
#
#        day1 logMAR        SPH        CYL       AXIS
# count    62.000000  62.000000  62.000000   62.00000
# mean      0.361594   1.096774  -2.080645   82.33871
# std       0.166216   0.888629   1.736053   29.24904
# min       0.000000  -2.250000  -5.750000   10.00000
# 25%       0.301030   0.500000  -2.937500   75.00000
# 50%       0.301030   1.000000  -2.125000   82.50000
# 75%       0.477121   1.750000  -1.250000   90.00000
# max       0.778151   3.000000   3.750000  175.00000

# %%
mixed_df[['AGE', 'SEX_numeric', 'KH', 'KV', 'AX','preop logMAR', 'day1 logMAR','SPH', 'CYL', 'AXIS']].corr()
# Out:
#                    AGE  SEX_numeric        KH        KV        AX  \
# AGE           1.000000     0.109071 -0.102660 -0.069459 -0.332723
# SEX_numeric   0.109071     1.000000  0.142471  0.156240 -0.155358
# KH           -0.102660     0.142471  1.000000  0.942065  0.170112
# KV           -0.069459     0.156240  0.942065  1.000000  0.137963
# AX           -0.332723    -0.155358  0.170112  0.137963  1.000000
# preop logMAR -0.201239    -0.026366 -0.045781 -0.023928  0.082546
# day1 logMAR   0.149601    -0.102973 -0.120587 -0.095271 -0.075959
# SPH           0.241529    -0.065939  0.108875  0.075072 -0.229575
# CYL          -0.382167     0.050137 -0.229944 -0.169472 -0.048304
# AXIS         -0.050750    -0.067005  0.018143  0.021459  0.123569
#
#               preop logMAR  day1 logMAR       SPH       CYL      AXIS
# AGE              -0.201239     0.149601  0.241529 -0.382167 -0.050750
# SEX_numeric      -0.026366    -0.102973 -0.065939  0.050137 -0.067005
# KH               -0.045781    -0.120587  0.108875 -0.229944  0.018143
# KV               -0.023928    -0.095271  0.075072 -0.169472  0.021459
# AX                0.082546    -0.075959 -0.229575 -0.048304  0.123569
# preop logMAR      1.000000     0.172540 -0.247751  0.166507  0.100990
# day1 logMAR       0.172540     1.000000  0.214834 -0.285474 -0.115694
# SPH              -0.247751     0.214834  1.000000 -0.541454 -0.091633
# CYL               0.166507    -0.285474 -0.541454  1.000000  0.092154
# AXIS              0.100990    -0.115694 -0.091633  0.092154  1.000000

# %%
day1AR.columns
# Out:
# Index(['AGE', 'SEX_numeric', 'KH', 'KV', 'AX', 'preop logMAR', 'day1 logMAR',
#        'SPH', 'CYL', 'AXIS', 'Classification'],
#       dtype='object')

# %%
day1logmar = day1AR[['preop logMAR','day1 logMAR']]
day1logmar
# Out:
#      preop logMAR  day1 logMAR
# 0        0.602060     0.301030
# 1        2.301030     0.477121
# 2        1.778151     0.477121
# 3        0.778151     0.301030
# 4        1.000000     0.602060
# ..            ...          ...
# 126      1.000000     0.602060
# 127      0.602060     0.176091
# 128      1.778151     0.301030
# 129      0.778151     0.477121
# 130      0.778151     0.602060
#
# [131 rows x 2 columns]

# %%
day1logmar.isnull().sum()
# Out:
# preop logMAR    0
# day1 logMAR     0
# dtype: int64

# %%
day1logmar.describe()
# Out:
#        preop logMAR  day1 logMAR
# count    131.000000   131.000000
# mean       1.337971     0.372322
# std        0.648344     0.200949
# min        0.000000     0.000000
# 25%        0.778151     0.176091
# 50%        1.301030     0.301030
# 75%        1.778151     0.477121
# max        2.778151     1.301030

# %%
day1logmar.hist()
# Out:
# array([[<Axes: title={'center': 'preop logMAR'}>,
#         <Axes: title={'center': 'day1 logMAR'}>]], dtype=object)

# %%
day1logmar.plot.box()
# Out:
# <Axes: >

# %%
import seaborn as sns
sns.pairplot(day1logmar)

# %%
day1logmar.corr()
# Out:
#               preop logMAR  day1 logMAR
# preop logMAR      1.000000     0.298275
# day1 logMAR       0.298275     1.000000
