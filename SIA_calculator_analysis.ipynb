# %% [markdown]
# <a href="https://colab.research.google.com/github/drskprabhakar/AI-ML-DL-colab-notebooks-coding-models/blob/main/SIA_calculator_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('/content/drive/MyDrive/Dr Aishwarya Raj thesis dataset 22424 keratometry reading.xlsx')

# %%
df.head()
# Out:
#              Name  pre-op KH  pre-op KV  pre-op Axis  post-op KH  post-op KV  \
# 0         madappa      43.50      44.00           90       43.25       44.75
# 1   puttalingaiah      44.25      44.50           45       41.25       44.50
# 2         savitha      47.75      49.50            5       46.00       47.75
# 3         devamma      43.75      44.75          165       42.75       45.00
# 4  nanjunda naika      44.25      44.75           85       44.50       45.50
#
#    post-op Axis  Unnamed: 7  App_magnitude  App_axis  Calc_magnitude  \
# 0            10         NaN          -0.36     1.290            1.04
# 1            70         NaN           2.07     4.010            3.42
# 2            35         NaN           2.47     0.076            1.75
# 3           150         NaN           0.51     1.640            1.47
# 4            40         NaN          -0.71     0.629            1.26
#
#    Calc_axis
# 0         105
# 1          68
# 2         155
# 3          50
# ...

# %%
df.columns
# Out:
# Index(['Name', 'pre-op KH', 'pre-op KV', 'pre-op Axis', 'post-op KH',
#        'post-op KV', 'post-op Axis', 'Unnamed: 7', 'App_magnitude', 'App_axis',
#        'Calc_magnitude', 'Calc_axis '],
#       dtype='object')

# %%
df1 = df.drop(['Name', 'pre-op KH', 'pre-op KV', 'pre-op Axis', 'post-op KH',
       'post-op KV', 'post-op Axis', 'Unnamed: 7'], axis=1)
df1.columns
# Out:
# Index(['App_magnitude', 'App_axis', 'Calc_magnitude', 'Calc_axis '], dtype='object')

# %%
df1.describe()
# Out:
#        App_magnitude    App_axis  Calc_magnitude  Calc_axis
# count     107.000000  107.000000      107.000000  107.000000
# mean       -0.159093    1.201355        1.490467  103.317757
# std         2.098488    2.074294        1.096741   91.731931
# min        -9.000000   -2.970000        0.170000    1.000000
# 25%        -0.747000    0.185000        0.785000   65.000000
# 50%        -0.019000    0.949000        1.260000   89.000000
# 75%         0.870000    1.781000        1.865000  123.000000
# max         5.396000   15.710000        6.530000  844.000000

# %%
df1.corr()
# Out:
#                 App_magnitude  App_axis  Calc_magnitude  Calc_axis
# App_magnitude        1.000000 -0.329449       -0.133723    0.107294
# App_axis            -0.329449  1.000000        0.554965   -0.067922
# Calc_magnitude      -0.133723  0.554965        1.000000   -0.044642
# Calc_axis            0.107294 -0.067922       -0.044642    1.000000

# %%
corr = df1.corr()
import seaborn
seaborn.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %%
df1.hist()
# Out:
# array([[<Axes: title={'center': 'App_magnitude'}>,
#         <Axes: title={'center': 'App_axis'}>],
#        [<Axes: title={'center': 'Calc_magnitude'}>,
#         <Axes: title={'center': 'Calc_axis '}>]], dtype=object)

# %%
df1.boxplot(['App_magnitude', 'Calc_magnitude'])
# Out:
# <Axes: >

# %%
seaborn.scatterplot(df1)
# Out:
# <Axes: >
