# %% [markdown]
# <a href="https://colab.research.google.com/github/drskprabhakar/AI-ML-DL-colab-notebooks-coding-models/blob/main/SIA_calculator_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('/content/drive/MyDrive/Dr Aishwarya Raj thesis dataset 1942024 raw data (1).xlsx')

# %%
df.head()
# Out:
#              Name  age  male  female  RE  LE  pre-op KH  pre-op KV  \
# 0         madappa   63     1       0   1   0      43.50      44.00
# 1   puttalingaiah   60     1       0   1   0      44.25      44.50
# 2         savitha   55     0       1   1   0      47.75      49.50
# 3         devamma   62     0       1   0   1      43.75      44.75
# 4  nanjunda naika   66     1       0   1   0      44.25      44.75
#
#    pre-op Axis  post-op KH  post-op KV  post-op Axis
# 0           90       43.25       44.75            10
# 1           45       41.25       44.50            70
# 2            5       46.00       47.75            35
# 3          165       42.75       45.00           150
# 4           85       44.50       45.50            40

# %%
df.columns
# Out:
# Index(['Name', 'age', 'male', 'female', 'RE', 'LE', 'pre-op KH', 'pre-op KV',
#        'pre-op Axis', 'post-op KH', 'post-op KV', 'post-op Axis'],
#       dtype='object')

# %%
df1 = df.drop(['Name','male','female','RE','LE'], axis=1)
df1.columns
# Out:
# Index(['age', 'pre-op KH', 'pre-op KV', 'pre-op Axis', 'post-op KH',
#        'post-op KV', 'post-op Axis'],
#       dtype='object')

# %%
df1.describe()
# Out:
#               age   pre-op KH   pre-op KV  pre-op Axis  post-op KH  \
# count  107.000000  107.000000  107.000000   107.000000  107.000000
# mean    62.775701   44.607477   45.518692    89.485981   44.238318
# std      4.788564    1.876528    1.757967    52.780851    2.151783
# min     52.000000   39.500000   42.250000     5.000000   35.750000
# 25%     60.000000   43.500000   44.375000    50.000000   43.000000
# 50%     63.000000   44.500000   45.500000    95.000000   44.500000
# 75%     65.000000   46.000000   46.875000   120.000000   45.875000
# max     88.000000   48.750000   49.500000   180.000000   48.000000
#
#        post-op KV  post-op Axis
# count  107.000000    107.000000
# mean    46.016355     96.962617
# std      2.238511     67.728499
# min     40.000000      5.000000
# 25%     44.750000     20.000000
# 50%     46.000000    100.000000
# 75%     47.500000    165.000000
# max     51.500000    180.000000

# %%
df1.corr()
# Out:
#                    age  pre-op KH  pre-op KV  pre-op Axis  post-op KH  \
# age           1.000000  -0.096504  -0.065617     0.180944   -0.104174
# pre-op KH    -0.096504   1.000000   0.916829     0.103075    0.765619
# pre-op KV    -0.065617   0.916829   1.000000     0.004807    0.741692
# pre-op Axis   0.180944   0.103075   0.004807     1.000000    0.034107
# post-op KH   -0.104174   0.765619   0.741692     0.034107    1.000000
# post-op KV   -0.163132   0.671647   0.716567    -0.041449    0.852625
# post-op Axis -0.113528  -0.077202  -0.148380     0.233510   -0.038762
#
#               post-op KV  post-op Axis
# age            -0.163132     -0.113528
# pre-op KH       0.671647     -0.077202
# pre-op KV       0.716567     -0.148380
# pre-op Axis    -0.041449      0.233510
# post-op KH      0.852625     -0.038762
# post-op KV      1.000000     -0.024481
# post-op Axis   -0.024481      1.000000

# %%
corr = df1.corr()
import seaborn
seaborn.heatmap(corr)
# Out:
# <Axes: >

# %%
df1.hist()
# Out:
# array([[<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'pre-op KH'}>,
#         <Axes: title={'center': 'pre-op KV'}>],
#        [<Axes: title={'center': 'pre-op Axis'}>,
#         <Axes: title={'center': 'post-op KH'}>,
#         <Axes: title={'center': 'post-op KV'}>],
#        [<Axes: title={'center': 'post-op Axis'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
df1.boxplot()
# Out:
# <Axes: >

# %%
seaborn.scatterplot(df1)
# Out:
# <Axes: >
