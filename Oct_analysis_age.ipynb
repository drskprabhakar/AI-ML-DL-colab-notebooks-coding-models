# %% [markdown]
# <a href="https://colab.research.google.com/github/drskprabhakar/AI-ML-DL-colab-notebooks-coding-models/blob/main/Oct_analysis_age.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn
import openpyxl

# %%
df=openpyxl.load_workbook('/content/drive/MyDrive/OCT analysis age original dataset in hemodialysis patients thesis Dr Poojitha.xlsx')
df.sheetnames
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Web Extension extension is not supported and will be removed
#   warn(msg)
# ['Patient-control demo (CKD-D (2)',
#  'Patient-control demo (CKD-DM)',
#  'Patient-control demo (CKD-HTN)',
#  'Pre+post HD-VA,IOP,CCT-DM',
#  'Pre+post HD-VA,IOP,CCT-HTN',
#  'Pre+post HD-RNFL-DM',
#  'Pre+post HD-CMT-DM',
#  'Pre+post HD-VFA-DM',
#  'Pre+post HD-RNFL-HTN',
#  'Pre+post HD-CMT-HTN',
#  'Pre+post HD-VFA-HTN']

# %%
age = pd.read_excel('/content/drive/MyDrive/OCT analysis age original dataset in hemodialysis patients thesis Dr Poojitha.xlsx', sheet_name='Patient-control demo (CKD-DM)')
age.columns
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Web Extension extension is not supported and will be removed
#   warn(msg)
# Index(['Age-DM', 'Age-HTN', 'Age-Control(DM)', 'Age-Control(HTN)'], dtype='object')

# %%
age.boxplot()
# Out:
# <Axes: >

# %%
age.corr()
# Out:
#                     Age-DM   Age-HTN  Age-Control(DM)  Age-Control(HTN)
# Age-DM            1.000000 -0.143775         0.185302          0.413496
# Age-HTN          -0.143775  1.000000        -0.501812         -0.018663
# Age-Control(DM)   0.185302 -0.501812         1.000000          0.235932
# Age-Control(HTN)  0.413496 -0.018663         0.235932          1.000000

# %%
seaborn.heatmap(age.corr(), annot=True)
# Out:
# <Axes: >

# %%
age.describe()
# Out:
#           Age-DM    Age-HTN  Age-Control(DM)  Age-Control(HTN)
# count  30.000000  30.000000        30.000000         30.000000
# mean   57.933333  56.433333        61.133333         62.100000
# std     5.112077  10.937702         8.818997         11.030835
# min    52.000000  35.000000        49.000000         42.000000
# 25%    54.250000  50.250000        55.250000         57.250000
# 50%    58.000000  56.500000        59.000000         61.000000
# 75%    58.750000  64.000000        66.500000         71.500000
# max    69.000000  74.000000        81.000000         84.000000

# %%
age.hist()
# Out:
# array([[<Axes: title={'center': 'Age-DM'}>,
#         <Axes: title={'center': 'Age-HTN'}>],
#        [<Axes: title={'center': 'Age-Control(DM)'}>,
#         <Axes: title={'center': 'Age-Control(HTN)'}>]], dtype=object)

# %%
seaborn.pairplot(age)

# %%
seaborn.displot(age)

# %%
seaborn.distplot(age)
# Out:
# <ipython-input-19-cc5aa82cb084>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   seaborn.distplot(age)
# <Axes: ylabel='Density'>

# %%
seaborn.scatterplot(age)
# Out:
# <Axes: >

# %%
seaborn.barplot(age)
# Out:
# <Axes: >

# %%
# prompt: T test for age

from scipy import stats
group1 = age['Age-DM']
group2 = age['Age-HTN']
stats.ttest_ind(group1, group2)
# Out:
# TtestResult(statistic=0.6804916101362404, pvalue=0.4989008056342147, df=58.0)

# %%
group3 = age['Age-Control(DM)']
group4 = age['Age-Control(HTN)']
stats.ttest_ind(group3, group4)
# Out:
# TtestResult(statistic=-0.3749004574218018, pvalue=0.7091018962686269, df=58.0)

# %%
group5 = age['Age-DM']
group6 = age['Age-Control(DM)']
stats.ttest_ind(group5, group6)
# Out:
# TtestResult(statistic=-1.7194360054945796, pvalue=0.09086799129939091, df=58.0)

# %%
group7 = age['Age-HTN']
group8 = age['Age-Control(HTN)']
stats.ttest_ind(group7, group8)
# Out:
# TtestResult(statistic=-1.998012749836596, pvalue=0.05041163132002393, df=58.0)

# %%
age.columns
# Out:
# Index(['Age-DM', 'Age-HTN', 'Age-Control(DM)', 'Age-Control(HTN)'], dtype='object')
