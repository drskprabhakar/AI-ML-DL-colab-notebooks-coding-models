# %% [markdown]
# <a href="https://colab.research.google.com/github/drskprabhakar/AI-ML-DL-colab-notebooks-coding-models/blob/main/Oct_analysis_(DM)_pre_n_post_dialysis_IOP_n_CCT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn
import openpyxl

# %%
df = openpyxl.load_workbook('/content/drive/MyDrive/OCT analysis original dataset in hemodialysis patients thesis Dr Poojitha.xlsx')
df.sheetnames
# Out:
# ['Patient-control demo (CKD-DM)',
#  'Patient-control demo (CKD-HTN)',
#  'Pre+post HD-VA,IOP,CCT-DM',
#  'Pre+post HD-VA,IOP,CCT-HTN',
#  'Pre+post HD-RNFL-DM',
#  'Pre+post HD-CMT-DM',
#  'Pre+post HD-VFA-DM',
#  'Pre+post HD-RNFL-HTN',
#  'Pre+post HD-CMT-HTN',
#  'Pre+post HD-VFA-HTN']

# %%
iopdm = pd.read_excel('/content/drive/MyDrive/OCT analysis original dataset in hemodialysis patients thesis Dr Poojitha.xlsx', sheet_name='Pre+post HD-VA,IOP,CCT-DM')
iopdm.columns
# Out:
# Index(['Pre HD BCVA-DM', 'Denominator', 'Numerator', 'Logmar', 'Pre HD IOP-DM',
#        'Pre HD CCT-DM', 'Post HD 1 wk BCVA-DM', 'Denominator.1', 'Numerator.1',
#        'Logmar.1', 'Post HD 1 wk IOP-DM', 'Post HD 1 wk CCT-DM',
#        'Post HD 4 wk BCVA-DM', 'Denominator.2', 'Numerator.2', 'Logmar.2',
#        'Post HD 4 wk IOP-DM', 'Post HD 4 wk CCT-DM', 'BCVA-DM-Control',
#        'Denominator.3', 'Numerator.3', 'Logmar.3', 'IOP-DM-Control',
#        'CCT-DM-Control'],
#       dtype='object')

# %%
iop_dm = iopdm.drop(['Pre HD BCVA-DM', 'Denominator', 'Numerator', 'Logmar',
       'Pre HD CCT-DM', 'Post HD 1 wk BCVA-DM', 'Denominator.1', 'Numerator.1',
       'Logmar.1', 'Post HD 1 wk CCT-DM',
       'Post HD 4 wk BCVA-DM', 'Denominator.2', 'Numerator.2', 'Logmar.2',
        'Post HD 4 wk CCT-DM', 'BCVA-DM-Control',
       'Denominator.3', 'Numerator.3', 'Logmar.3',
       'CCT-DM-Control'], axis=1)
iop_dm.columns
# Out:
# Index(['Pre HD IOP-DM', 'Post HD 1 wk IOP-DM', 'Post HD 4 wk IOP-DM',
#        'IOP-DM-Control'],
#       dtype='object')

# %%
iop_dm.describe()
# Out:
#        Pre HD IOP-DM  Post HD 1 wk IOP-DM  Post HD 4 wk IOP-DM  IOP-DM-Control
# count      30.000000            30.000000            30.000000       30.000000
# mean       17.000000            17.033333            15.966667       14.866667
# std         3.184012             2.413801             2.747831        3.729966
# min        12.000000            12.000000            11.000000       11.000000
# 25%        14.250000            17.000000            14.000000       12.000000
# 50%        17.000000            17.000000            16.000000       14.000000
# 75%        18.750000            17.750000            18.000000       16.000000
# max        26.000000            23.000000            22.000000       26.000000

# %%
iop_dm.corr()
# Out:
#                      Pre HD IOP-DM  Post HD 1 wk IOP-DM  Post HD 4 wk IOP-DM  \
# Pre HD IOP-DM             1.000000             0.856957             0.945907
# Post HD 1 wk IOP-DM       0.856957             1.000000             0.831995
# Post HD 4 wk IOP-DM       0.945907             0.831995             1.000000
# IOP-DM-Control            0.098719             0.352868             0.174500
#
#                      IOP-DM-Control
# Pre HD IOP-DM              0.098719
# Post HD 1 wk IOP-DM        0.352868
# Post HD 4 wk IOP-DM        0.174500
# IOP-DM-Control             1.000000

# %%
seaborn.heatmap(iop_dm.corr(), annot=True)
# Out:
# <Axes: >

# %%
iop_dm.hist()
# Out:
# array([[<Axes: title={'center': 'Pre HD IOP-DM'}>,
#         <Axes: title={'center': 'Post HD 1 wk IOP-DM'}>],
#        [<Axes: title={'center': 'Post HD 4 wk IOP-DM'}>,
#         <Axes: title={'center': 'IOP-DM-Control'}>]], dtype=object)

# %%
iop_dm.boxplot()
# Out:
# <Axes: >

# %%
seaborn.pairplot(iop_dm)

# %%
seaborn.barplot(iop_dm)
# Out:
# <Axes: >

# %%
seaborn.scatterplot(iop_dm)
# Out:
# <Axes: >

# %%
seaborn.distplot(iop_dm)
# Out:
# <ipython-input-17-efc8f39b4d58>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   seaborn.distplot(iop_dm)
# <Axes: ylabel='Density'>

# %%
seaborn.kdeplot(iop_dm)
# Out:
# <Axes: ylabel='Density'>

# %%
from scipy import stats

# Assuming your 'Pre HD logMAR-DM' and 'Post HD 1 wk logMAR-DM' columns are in the DataFrame 'vision_dm'
pre_iop = iop_dm['Pre HD IOP-DM']
post_iop = iop_dm['Post HD 1 wk IOP-DM']

# Perform the t-test
t_statistic, p_value = stats.ttest_rel(pre_iop, post_iop)

print("T-statistic:", t_statistic)
print("P-value:", p_value)
# Out:
# T-statistic: -0.10926604951199244
# P-value: 0.9137440636558987

# %%
pre_iop = iop_dm['Pre HD IOP-DM']
post_iop = iop_dm['Post HD 4 wk IOP-DM']

# Perform the t-test
t_statistic, p_value = stats.ttest_rel(pre_iop, post_iop)

print("T-statistic:", t_statistic)
print("P-value:", p_value)
# Out:
# T-statistic: 5.308386633922525
# P-value: 1.076604652902136e-05

# %%
pre_iop = iop_dm['Pre HD IOP-DM']
post_iop = iop_dm['IOP-DM-Control']

# Perform the t-test
t_statistic, p_value = stats.ttest_rel(pre_iop, post_iop)

print("T-statistic:", t_statistic)
print("P-value:", p_value)
# Out:
# T-statistic: 2.5080256688822153
# P-value: 0.01798840166501934

# %%
iop_dm.columns
# Out:
# Index(['Pre HD IOP-DM', 'Post HD 1 wk IOP-DM', 'Post HD 4 wk IOP-DM',
#        'IOP-DM-Control'],
#       dtype='object')

# %% [markdown]
# ## CCT Analysis

# %%
cctdm = pd.read_excel('/content/drive/MyDrive/OCT analysis original dataset in hemodialysis patients thesis Dr Poojitha.xlsx', sheet_name='Pre+post HD-VA,IOP,CCT-DM')
iopdm.columns
# Out:
# Index(['Pre HD BCVA-DM', 'Denominator', 'Numerator', 'Logmar', 'Pre HD IOP-DM',
#        'Pre HD CCT-DM', 'Post HD 1 wk BCVA-DM', 'Denominator.1', 'Numerator.1',
#        'Logmar.1', 'Post HD 1 wk IOP-DM', 'Post HD 1 wk CCT-DM',
#        'Post HD 4 wk BCVA-DM', 'Denominator.2', 'Numerator.2', 'Logmar.2',
#        'Post HD 4 wk IOP-DM', 'Post HD 4 wk CCT-DM', 'BCVA-DM-Control',
#        'Denominator.3', 'Numerator.3', 'Logmar.3', 'IOP-DM-Control',
#        'CCT-DM-Control'],
#       dtype='object')

# %%
cct_dm = cctdm.drop(['Pre HD BCVA-DM', 'Denominator', 'Numerator', 'Logmar', 'Pre HD IOP-DM',
       'Post HD 1 wk BCVA-DM', 'Denominator.1', 'Numerator.1',
       'Logmar.1', 'Post HD 1 wk IOP-DM',
       'Post HD 4 wk BCVA-DM', 'Denominator.2', 'Numerator.2', 'Logmar.2',
       'Post HD 4 wk IOP-DM', 'BCVA-DM-Control',
       'Denominator.3', 'Numerator.3', 'Logmar.3', 'IOP-DM-Control'], axis=1)
cct_dm.columns
# Out:
# Index(['Pre HD CCT-DM', 'Post HD 1 wk CCT-DM', 'Post HD 4 wk CCT-DM',
#        'CCT-DM-Control'],
#       dtype='object')

# %%
cct_dm.corr()
# Out:
#                      Pre HD CCT-DM  Post HD 1 wk CCT-DM  Post HD 4 wk CCT-DM  \
# Pre HD CCT-DM             1.000000             0.925357             0.831789
# Post HD 1 wk CCT-DM       0.925357             1.000000             0.725394
# Post HD 4 wk CCT-DM       0.831789             0.725394             1.000000
# CCT-DM-Control            0.389623             0.317695             0.407148
#
#                      CCT-DM-Control
# Pre HD CCT-DM              0.389623
# Post HD 1 wk CCT-DM        0.317695
# Post HD 4 wk CCT-DM        0.407148
# CCT-DM-Control             1.000000

# %%
seaborn.heatmap(cct_dm.corr(), annot=True)
# Out:
# <Axes: >

# %%
seaborn.barplot(cct_dm)
# Out:
# <Axes: >

# %%
cct_dm.hist()
# Out:
# array([[<Axes: title={'center': 'Pre HD CCT-DM'}>,
#         <Axes: title={'center': 'Post HD 1 wk CCT-DM'}>],
#        [<Axes: title={'center': 'Post HD 4 wk CCT-DM'}>,
#         <Axes: title={'center': 'CCT-DM-Control'}>]], dtype=object)

# %%
cct_dm.boxplot()
# Out:
# <Axes: >

# %%
seaborn.kdeplot(cct_dm)
# Out:
# <Axes: ylabel='Density'>

# %%
seaborn.distplot(cct_dm)
# Out:
# <ipython-input-34-d82dbc5ff85b>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   seaborn.distplot(cct_dm)
# <Axes: ylabel='Density'>

# %%
seaborn.pairplot(cct_dm)

# %%
from scipy import stats

# Assuming your 'Pre HD logMAR-DM' and 'Post HD 1 wk logMAR-DM' columns are in the DataFrame 'vision_dm'
pre_cct = cct_dm['Pre HD CCT-DM']
post_cct = cct_dm['Post HD 1 wk CCT-DM']

# Perform the t-test
t_statistic, p_value = stats.ttest_rel(pre_cct, post_cct)

print("T-statistic:", t_statistic)
print("P-value:", p_value)
# Out:
# T-statistic: 0.5692340123335052
# P-value: 0.5735802768514733

# %%
pre_cct = cct_dm['Pre HD CCT-DM']
post_cct = cct_dm['Post HD 4 wk CCT-DM']

# Perform the t-test
t_statistic, p_value = stats.ttest_rel(pre_cct, post_cct)

print("T-statistic:", t_statistic)
print("P-value:", p_value)
# Out:
# T-statistic: 1.9634887857776717
# P-value: 0.05924207924043287

# %%
pre_cct = cct_dm['Pre HD CCT-DM']
post_cct = cct_dm['CCT-DM-Control']

# Perform the t-test
t_statistic, p_value = stats.ttest_rel(pre_cct, post_cct)

print("T-statistic:", t_statistic)
print("P-value:", p_value)
# Out:
# T-statistic: -0.13235068963695715
# P-value: 0.8956209616631184

# %%
cct_dm.columns
# Out:
# Index(['Pre HD CCT-DM', 'Post HD 1 wk CCT-DM', 'Post HD 4 wk CCT-DM',
#        'CCT-DM-Control'],
#       dtype='object')
