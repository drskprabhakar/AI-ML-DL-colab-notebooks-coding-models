# %% [markdown]
# <a href="https://colab.research.google.com/github/drskprabhakar/Axial-Length-Prediction-ML-Regression-mode/blob/main/Axial_length_prediction_regression_algorithm_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import libraries
import pandas as pd # is used to make exploratory data analysis
import numpy as np # is numerical math library in python for formulas and calculations

# %%
# loading dataset from google MyDrive
data = pd.read_excel('/content/drive/MyDrive/Axial length prediction dataset.xlsx')

# %%
# explora the dataset
data.shape
# Out:
# (108, 3)

# %%
data.columns
# Out:
# Index(['KH', 'KV', 'AL'], dtype='object')

# %%
data.head()
# Out:
#      KH     KV     AL
# 0  41.5  40.50  20.30
# 1  41.5  40.50  20.56
# 2  41.5  40.50  20.61
# 3  41.5  40.75  20.79
# 4  42.0  41.00  21.10

# %%
data.tail()
# Out:
#         KH    KV     AL
# 103  47.25  47.0  23.90
# 104  47.50  47.5  24.00
# 105  47.50  47.5  24.04
# 106  47.75  48.0  24.08
# 107  47.75  48.5  24.20

# %%
data.describe()
# Out:
#                KH          KV          AL
# count  108.000000  108.000000  108.000000
# mean    44.756481   44.129167   22.704167
# std      1.551636    1.760219    0.791164
# min     41.500000   40.500000   20.300000
# 25%     43.500000   42.750000   22.305000
# 50%     44.750000   44.000000   22.775000
# 75%     46.000000   45.500000   23.222500
# max     47.750000   48.500000   24.200000

# %% [markdown]
# # data cleaning, refining, preprocessing

# %%
data.isnull().sum()
# Out:
# KH    0
# KV    0
# AL    0
# dtype: int64

# %%
data.info()

# %% [markdown]
# # Define x and y variables

# %%
x = data.drop(['AL'], axis=1).values
y = data['AL'].values

# %% [markdown]
# # Spliting the dataset for train test and split

# %%
from sklearn.model_selection import train_test_split
x_train, y_train, x_test, y_test = train_test_split(x,y, test_size=0.3, random_state=0)

# %% [markdown]
# # fitting the model for training with linear regression function imported from sklearn.linear_model

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x, y)
# Out:
# LinearRegression()

# %% [markdown]
# # Evaluating the model on test set

# %%
predicted = model.predict(x)

# %% [markdown]
# # find out accuracy metrics

# %%
model.score(x,y)
# Out:
# 0.9648064807642383

# %%
from sklearn.metrics import r2_score
actual = y
r2_score(actual, predicted)
# Out:
# 0.9648064807642383

# %% [markdown]
# # Verify the model

# %%
model.predict([[47.75,	48.5]])
# Out:
# array([24.30506019])

# %%
data.tail()
# Out:
#         KH    KV     AL
# 103  47.25  47.0  23.90
# 104  47.50  47.5  24.00
# 105  47.50  47.5  24.04
# 106  47.75  48.0  24.08
# 107  47.75  48.5  24.20
