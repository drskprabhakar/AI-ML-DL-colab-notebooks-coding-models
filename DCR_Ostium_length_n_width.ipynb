# %% [markdown]
# <a href="https://colab.research.google.com/github/drskprabhakar/AI-ML-DL-colab-notebooks-coding-models/blob/main/DCR_Ostium_length_n_width.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('/content/drive/MyDrive/Book.xlsx')

# %%
df.shape
# Out:
# (25, 8)

# %%
df.head()
# Out:
#     Intraop EXT_DCR (L)  post op Day 1 EXT_DCR(L)  \
# 0                    14                     13.62
# 1                    15                     14.69
# 2                    17                     17.00
# 3                    12                     12.00
# 4                     9                      9.00
#
#    post op 1 month EXT_DCR (L)   Post op 3 months EXT DCR (L)  \
# 0                         13.0                           12.9
# 1                         14.0                           13.5
# 2                         16.5                           16.5
# 3                         11.0                           10.8
# 4                          8.3                            8.2
#
#    intraop ENDO_DCR (L)  post op Day 1 Endo_DCR (L)  \
# 0                  11.0                        11.0
# 1                  13.0                        13.0
# 2                  11.0                        11.0
# 3                  11.0                        11.3
# ...

# %%
df.tail()
# Out:
#      Intraop EXT_DCR (L)  post op Day 1 EXT_DCR(L)  \
# 20                    12                      12.0
# 21                     8                       8.0
# 22                    14                      14.0
# 23                    16                      16.0
# 24                    12                      12.0
#
#     post op 1 month EXT_DCR (L)   Post op 3 months EXT DCR (L)  \
# 20                        11.40                           11.6
# 21                         7.38                            7.4
# 22                        13.07                           13.0
# 23                        15.68                           15.4
# 24                        11.40                           11.0
#
#     intraop ENDO_DCR (L)  post op Day 1 Endo_DCR (L)  \
# 20                   9.5                         9.6
# 21                  10.0                        10.0
# 22                  11.0                        10.8
# 23                   9.0                         8.9
# ...

# %%
df.columns
# Out:
# Index([' Intraop EXT_DCR (L)', 'post op Day 1 EXT_DCR(L)',
#        'post op 1 month EXT_DCR (L)', ' Post op 3 months EXT DCR (L)',
#        'intraop ENDO_DCR (L)', 'post op Day 1 Endo_DCR (L)',
#        'Post op 1 month Endo_DCR(L)', ' Post op 3 months Endo DCR (L)'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0    Intraop EXT_DCR (L)            25 non-null     int64
#  1   post op Day 1 EXT_DCR(L)        25 non-null     float64
#  2   post op 1 month EXT_DCR (L)     25 non-null     float64
#  3    Post op 3 months EXT DCR (L)   25 non-null     float64
#  4   intraop ENDO_DCR (L)            25 non-null     float64
#  5   post op Day 1 Endo_DCR (L)      25 non-null     float64
#  6   Post op 1 month Endo_DCR(L)     25 non-null     float64
#  7    Post op 3 months Endo DCR (L)  25 non-null     float64
# dtypes: float64(7), int64(1)
# memory usage: 1.7 KB

# %%
df.isnull()
# Out:
#      Intraop EXT_DCR (L)  post op Day 1 EXT_DCR(L)  \
# 0                  False                     False
# 1                  False                     False
# 2                  False                     False
# 3                  False                     False
# 4                  False                     False
# 5                  False                     False
# 6                  False                     False
# 7                  False                     False
# 8                  False                     False
# 9                  False                     False
# 10                 False                     False
# 11                 False                     False
# 12                 False                     False
# 13                 False                     False
# 14                 False                     False
# 15                 False                     False
# 16                 False                     False
# ...

# %%
df.isnull().sum()
# Out:
#  Intraop EXT_DCR (L)              0
# post op Day 1 EXT_DCR(L)          0
# post op 1 month EXT_DCR (L)       0
#  Post op 3 months EXT DCR (L)     0
# intraop ENDO_DCR (L)              0
# post op Day 1 Endo_DCR (L)        0
# Post op 1 month Endo_DCR(L)       0
#  Post op 3 months Endo DCR (L)    0
# dtype: int64

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index([' Intraop EXT_DCR (L)', 'post op Day 1 EXT_DCR(L)',
#        'post op 1 month EXT_DCR (L)', ' Post op 3 months EXT DCR (L)',
#        'intraop ENDO_DCR (L)', 'post op Day 1 Endo_DCR (L)',
#        'Post op 1 month Endo_DCR(L)', ' Post op 3 months Endo DCR (L)'],
#       dtype='object')

# %%
df.boxplot(column=['intraop ENDO_DCR (L)', 'post op Day 1 Endo_DCR (L)','Post op 1 month Endo_DCR(L)', ' Post op 3 months Endo DCR (L)'])
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#         Intraop EXT_DCR (L)  post op Day 1 EXT_DCR(L)  \
# count                 25.00                 25.000000
# mean                  12.48                 12.484400
# std                    2.40                  2.369374
# min                    8.00                  8.000000
# 25%                   11.00                 11.000000
# 50%                   12.00                 12.000000
# 75%                   14.00                 14.000000
# max                   17.00                 17.000000
#
#        post op 1 month EXT_DCR (L)   Post op 3 months EXT DCR (L)  \
# count                    25.000000                      25.000000
# mean                     11.960400                      11.668000
# std                       2.407756                       2.125386
# min                       7.380000                       7.400000
# 25%                      10.500000                      10.500000
# 50%                      11.500000                      11.600000
# ...

# %%
df.corr()
# Out:
#                                  Intraop EXT_DCR (L)  \
#  Intraop EXT_DCR (L)                        1.000000
# post op Day 1 EXT_DCR(L)                    0.997957
# post op 1 month EXT_DCR (L)                 0.989534
#  Post op 3 months EXT DCR (L)               0.887780
# intraop ENDO_DCR (L)                        0.068943
# post op Day 1 Endo_DCR (L)                  0.112461
# Post op 1 month Endo_DCR(L)                 0.116803
#  Post op 3 months Endo DCR (L)              0.254008
#
#                                 post op Day 1 EXT_DCR(L)  \
#  Intraop EXT_DCR (L)                            0.997957
# post op Day 1 EXT_DCR(L)                        1.000000
# post op 1 month EXT_DCR (L)                     0.991474
#  Post op 3 months EXT DCR (L)                   0.883448
# intraop ENDO_DCR (L)                            0.063373
# post op Day 1 Endo_DCR (L)                      0.108352
# Post op 1 month Endo_DCR(L)                     0.110827
# ...

# %%
import seaborn
seaborn.heatmap(df.corr())
# Out:
# <Axes: >

# %%
seaborn.histplot(df)
# Out:
# <Axes: ylabel='Count'>

# %%
seaborn.distplot(df)
# Out:
# <ipython-input-5-59595f08b577>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   seaborn.distplot(df)
# <Axes: ylabel='Density'>

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': ' Intraop EXT_DCR (L)'}>,
#         <Axes: title={'center': 'post op Day 1 EXT_DCR(L)'}>,
#         <Axes: title={'center': 'post op 1 month EXT_DCR (L)'}>],
#        [<Axes: title={'center': ' Post op 3 months EXT DCR (L)'}>,
#         <Axes: title={'center': 'intraop ENDO_DCR (L)'}>,
#         <Axes: title={'center': 'post op Day 1 Endo_DCR (L)'}>],
#        [<Axes: title={'center': 'Post op 1 month Endo_DCR(L)'}>,
#         <Axes: title={'center': ' Post op 3 months Endo DCR (L)'}>,
#         <Axes: >]], dtype=object)

# %%
seaborn.pairplot(df)

# %%
seaborn.scatterplot(df)
# Out:
# <Axes: >

# %%
# !pip install pandas openpyxl

# %%
# List all sheet names
xls = pd.ExcelFile('/content/drive/MyDrive/Book.xlsx')
print(xls.sheet_names)

# Read a specific sheet by name
df_OL = pd.read_excel('/content/drive/MyDrive/Book.xlsx', sheet_name='Ostium length ')

# Read a specific sheet by index
df_OW = pd.read_excel('/content/drive/MyDrive/Book.xlsx', sheet_name='Ostium width')
# Out:
# ['Ostium length ', 'Ostium width']

# %%
df_OW.describe()
# Out:
#        Intraop EXT_DCR (W)  Post op Day 1 EXT_DCR (W)  \
# count            25.000000                  25.000000
# mean              8.100000                   8.066800
# std               1.547848                   1.532364
# min               5.000000                   5.000000
# 25%               7.000000                   7.000000
# 50%               8.000000                   8.000000
# 75%               9.000000                   9.000000
# max              11.000000                  11.000000
#
#        Post op 1 month EXT_DCR (W)   Post op 3 months EXT DCR (W)  \
# count                    25.000000                      25.000000
# mean                      7.529600                       7.093600
# std                       1.443605                       1.281756
# min                       4.500000                       4.400000
# 25%                       6.500000                       6.300000
# 50%                       7.800000                       7.090000
# ...

# %%
df_OW.boxplot()
# Out:
# <Axes: >

# %%
df_OW.hist()
# Out:
# array([[<Axes: title={'center': 'Intraop EXT_DCR (W)'}>,
#         <Axes: title={'center': 'Post op Day 1 EXT_DCR (W)'}>,
#         <Axes: title={'center': 'Post op 1 month EXT_DCR (W)'}>],
#        [<Axes: title={'center': ' Post op 3 months EXT DCR (W)'}>,
#         <Axes: title={'center': 'Intraop Endo_DCR (W)'}>,
#         <Axes: title={'center': 'Post op day 1 Endo_DCR (W)'}>],
#        [<Axes: title={'center': 'Post op 1 Month Endo_DCR (W)'}>,
#         <Axes: title={'center': 'Post op 3 months Endo_DCR (W)'}>,
#         <Axes: >]], dtype=object)
