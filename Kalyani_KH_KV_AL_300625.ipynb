# %% [markdown]
# <a href="https://colab.research.google.com/github/drskprabhakar/AI-ML-DL-colab-notebooks-coding-models/blob/main/Kalyani_KH_KV_AL_300625.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel('/content/Dr Kalyani thesis KH_KV_AL training data cleaned.xlsx')
df.shape, df.columns
# Out:
# ((2001, 3), Index(['KH', 'KV', 'AL(actual)'], dtype='object'))

# %%
x=df[['KH', 'KV']]
y=df['AL(actual)']

# %%
# prompt: Linear regression

import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# Create and train the Linear Regression model
regressor = LinearRegression()
regressor.fit(X_train, y_train)

# Make predictions on the test data
y_pred = regressor.predict(X_test)

# Evaluate the model (optional)
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('R-squared:', metrics.r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error: 0.8055838405315947
# Mean Squared Error: 1.1812578683384567
# Root Mean Squared Error: 1.0868568757377655
# R-squared: 0.05676934804462852

# %%
# prompt: Random forest

import numpy as np
from sklearn.ensemble import RandomForestRegressor

# Create and train the Random Forest Regressor model
# You can adjust parameters like n_estimators, random_state, etc.
rf_regressor = RandomForestRegressor(n_estimators=100, random_state=0)
rf_regressor.fit(X_train, y_train)

# Make predictions on the test data
y_pred_rf = rf_regressor.predict(X_test)

# Evaluate the Random Forest model
print('\nRandom Forest Model Evaluation:')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_rf))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_rf))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_rf)))
print('R-squared:', metrics.r2_score(y_test, y_pred_rf))
# Out:
# Random Forest Model Evaluation:
# Mean Absolute Error: 0.8926053911651766
# Mean Squared Error: 1.4590041009899803
# Root Mean Squared Error: 1.2078924211162103
# R-squared: -0.16501013560913225

# %%
# prompt: Decision tree

import numpy as np
from sklearn.tree import DecisionTreeRegressor

# Create and train the Decision Tree Regressor model
# You can adjust parameters like max_depth, random_state, etc.
dt_regressor = DecisionTreeRegressor(random_state=0)
dt_regressor.fit(X_train, y_train)

# Make predictions on the test data
y_pred_dt = dt_regressor.predict(X_test)

# Evaluate the Decision Tree model
print('\nDecision Tree Model Evaluation:')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_dt))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_dt))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_dt)))
print('R-squared:', metrics.r2_score(y_test, y_pred_dt))
# Out:
# Decision Tree Model Evaluation:
# Mean Absolute Error: 0.9282204706426688
# Mean Squared Error: 1.5510405822470419
# Root Mean Squared Error: 1.2454077975695519
# R-squared: -0.2385009732548402

# %%
# prompt: Svm

import numpy as np
from sklearn.svm import SVR

# Create and train the Support Vector Regressor model
# You can adjust parameters like kernel, C, epsilon, etc.
svm_regressor = SVR(kernel='rbf') # Radial Basis Function kernel is common
svm_regressor.fit(X_train, y_train)

# Make predictions on the test data
y_pred_svm = svm_regressor.predict(X_test)

# Evaluate the SVM model
print('\nSupport Vector Machine (SVM) Model Evaluation:')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_svm))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_svm))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_svm)))
print('R-squared:', metrics.r2_score(y_test, y_pred_svm))
# Out:
# Support Vector Machine (SVM) Model Evaluation:
# Mean Absolute Error: 0.7947561408778364
# Mean Squared Error: 1.1905300883154875
# Root Mean Squared Error: 1.0911141499932477
# R-squared: 0.049365509874805036

# %%
# prompt: Knn

import numpy as np
from sklearn.neighbors import KNeighborsRegressor

# Create and train the K-Nearest Neighbors Regressor model
# You can adjust parameters like n_neighbors (number of neighbors)
knn_regressor = KNeighborsRegressor(n_neighbors=5) # Using 5 neighbors as a default
knn_regressor.fit(X_train, y_train)

# Make predictions on the test data
y_pred_knn = knn_regressor.predict(X_test)

# Evaluate the KNN model
print('\nK-Nearest Neighbors (KNN) Model Evaluation:')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_knn))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_knn))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_knn)))
print('R-squared:', metrics.r2_score(y_test, y_pred_knn))
# Out:
# K-Nearest Neighbors (KNN) Model Evaluation:
# Mean Absolute Error: 0.8838044887780547
# Mean Squared Error: 1.3609647824438902
# Root Mean Squared Error: 1.1666039526951253
# R-squared: -0.08672605147468215

# %%
# prompt: XGboost

import numpy as np
# !pip install xgboost

import xgboost as xgb

# Create and train the XGBoost Regressor model
# You can adjust parameters like n_estimators, learning_rate, max_depth, etc.
# Common parameters: 'objective', 'n_estimators', 'learning_rate', 'max_depth', 'subsample', 'colsample_bytree', 'reg_alpha', 'reg_lambda'
xgb_regressor = xgb.XGBRegressor(objective='reg:squarederror', # Common objective for regression
                                 n_estimators=100,
                                 learning_rate=0.1,
                                 max_depth=3,
                                 random_state=0) # Ensure reproducibility
xgb_regressor.fit(X_train, y_train)

# Make predictions on the test data
y_pred_xgb = xgb_regressor.predict(X_test)

# Evaluate the XGBoost model
print('\nXGBoost Model Evaluation:')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_xgb))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_xgb))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_xgb)))
print('R-squared:', metrics.r2_score(y_test, y_pred_xgb))
# Out:
# ...
#
# XGBoost Model Evaluation:
# Mean Absolute Error: 0.8250937253043537
# Mean Squared Error: 1.2327339321579234
# Root Mean Squared Error: 1.1102855183050544
# R-squared: 0.01566587475743919

# %%
# prompt: OLS

import numpy as np
# !pip install statsmodels
import statsmodels.api as sm

# Add a constant (intercept) to the independent variables
X_train_sm = sm.add_constant(X_train)
X_test_sm = sm.add_constant(X_test)

# Create and fit the OLS model
ols_model = sm.OLS(y_train, X_train_sm)
ols_results = ols_model.fit()

# Print the summary of the OLS model
print(ols_results.summary())

# Make predictions on the test data using the OLS model
y_pred_ols = ols_results.predict(X_test_sm)

# Evaluate the OLS model
print('\nOLS Model Evaluation:')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_ols))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_ols))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_ols)))
print('R-squared:', metrics.r2_score(y_test, y_pred_ols))
# Out:
# ...
#                             OLS Regression Results
# ...
# Dep. Variable:             AL(actual)   R-squared:                       0.053
# Model:                            OLS   Adj. R-squared:                  0.051
# Method:                 Least Squares   F-statistic:                     44.25
# Date:                Mon, 30 Jun 2025   Prob (F-statistic):           1.98e-19
# Time:                        02:00:20   Log-Likelihood:                -2606.1
# No. Observations:                1600   AIC:                             5218.
# Df Residuals:                    1597   BIC:                             5234.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         30.2946      0.826     36.689      0.000      28.675      31.914
# ...

# %%
# prompt: Pca

import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Standardize the data before applying PCA
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Apply PCA
# n_components can be an integer (number of components) or a float between 0 and 1
# If float, it represents the percentage of variance to be explained.
# For example, n_components=1 would reduce to 1 principal component.
# For simplicity with 2 features, we'll set n_components=1
pca = PCA(n_components=1)

# Fit PCA on the training data and transform both training and testing data
X_train_pca = pca.fit_transform(X_train_scaled)
X_test_pca = pca.transform(X_test_scaled)

print("\nOriginal number of features:", X_train.shape[1])
print("Number of features after PCA:", X_train_pca.shape[1])

# You can now use X_train_pca and X_test_pca in your regression models.
# For example, train a Linear Regression model on the PCA reduced data:
lr_pca = LinearRegression()
lr_pca.fit(X_train_pca, y_train)

# Make predictions on the PCA test data
y_pred_lr_pca = lr_pca.predict(X_test_pca)

# Evaluate the Linear Regression model on PCA data
print('\nLinear Regression Model Evaluation (after PCA):')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_lr_pca))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_lr_pca))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_lr_pca)))
print('R-squared:', metrics.r2_score(y_test, y_pred_lr_pca))

# Explained variance ratio: tells you how much variance is explained by each principal component
print("\nExplained variance ratio by principal components:", pca.explained_variance_ratio_)
print("Total explained variance:", sum(pca.explained_variance_ratio_))
# Out:
# Original number of features: 2
# Number of features after PCA: 1
#
# Linear Regression Model Evaluation (after PCA):
# Mean Absolute Error: 0.8028518900375219
# Mean Squared Error: 1.1793388543731262
# Root Mean Squared Error: 1.0859736895400027
# R-squared: 0.058301674594271824
#
# Explained variance ratio by principal components: [0.89960147]
# Total explained variance: 0.8996014654595744

# %%
# prompt: OLS after pca

import numpy as np
# Apply OLS regression on the PCA transformed data
# Add a constant (intercept) to the PCA independent variables for statsmodels
X_train_pca_sm = sm.add_constant(X_train_pca)
X_test_pca_sm = sm.add_constant(X_test_pca)

# Create and fit the OLS model on PCA data
ols_pca_model = sm.OLS(y_train, X_train_pca_sm)
ols_pca_results = ols_pca_model.fit()

# Print the summary of the OLS model on PCA data
print(ols_pca_results.summary())

# Make predictions on the PCA test data using the OLS model
y_pred_ols_pca = ols_pca_results.predict(X_test_pca_sm)

# Evaluate the OLS model on PCA data
print('\nOLS Model Evaluation (after PCA):')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_ols_pca))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_ols_pca))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_ols_pca)))
print('R-squared:', metrics.r2_score(y_test, y_pred_ols_pca))
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             AL(actual)   R-squared:                       0.050
# Model:                            OLS   Adj. R-squared:                  0.049
# Method:                 Least Squares   F-statistic:                     84.07
# Date:                Mon, 30 Jun 2025   Prob (F-statistic):           1.43e-19
# Time:                        02:02:18   Log-Likelihood:                -2608.3
# No. Observations:                1600   AIC:                             5221.
# Df Residuals:                    1598   BIC:                             5231.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         23.0051      0.031    744.519      0.000      22.944      23.066
# ...

# %%
# prompt: Random forest after pca

import numpy as np
# Apply Random Forest Regressor on the PCA transformed data
rf_regressor_pca = RandomForestRegressor(n_estimators=100, random_state=0)
rf_regressor_pca.fit(X_train_pca, y_train)

# Make predictions on the PCA test data
y_pred_rf_pca = rf_regressor_pca.predict(X_test_pca)

# Evaluate the Random Forest model on PCA data
print('\nRandom Forest Model Evaluation (after PCA):')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_rf_pca))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_rf_pca))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_rf_pca)))
print('R-squared:', metrics.r2_score(y_test, y_pred_rf_pca))
# Out:
# Random Forest Model Evaluation (after PCA):
# Mean Absolute Error: 0.9112832231319682
# Mean Squared Error: 1.5214717503380255
# Root Mean Squared Error: 1.2334795297604357
# R-squared: -0.21489035499218212

# %%
# prompt: Knn

import numpy as np
# K-Nearest Neighbors Regressor model on PCA transformed data
knn_regressor_pca = KNeighborsRegressor(n_neighbors=5)
knn_regressor_pca.fit(X_train_pca, y_train)

# Make predictions on the PCA test data
y_pred_knn_pca = knn_regressor_pca.predict(X_test_pca)

# Evaluate the KNN model on PCA data
print('\nK-Nearest Neighbors (KNN) Model Evaluation (after PCA):')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_knn_pca))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_knn_pca))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_knn_pca)))
print('R-squared:', metrics.r2_score(y_test, y_pred_knn_pca))
# Out:
# K-Nearest Neighbors (KNN) Model Evaluation (after PCA):
# Mean Absolute Error: 0.9174942643391519
# Mean Squared Error: 1.514726936259351
# Root Mean Squared Error: 1.2307424329482393
# R-squared: -0.20950464239608801

# %%
# prompt: Decision tree

import numpy as np
# Decision Tree Regressor model on PCA transformed data
dt_regressor_pca = DecisionTreeRegressor(random_state=0)
dt_regressor_pca.fit(X_train_pca, y_train)

# Make predictions on the PCA test data
y_pred_dt_pca = dt_regressor_pca.predict(X_test_pca)

# Evaluate the Decision Tree model on PCA data
print('\nDecision Tree Model Evaluation (after PCA):')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_dt_pca))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_dt_pca))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_dt_pca)))
print('R-squared:', metrics.r2_score(y_test, y_pred_dt_pca))
# Out:
# Decision Tree Model Evaluation (after PCA):
# Mean Absolute Error: 0.9389673939188937
# Mean Squared Error: 1.612928326172519
# Root Mean Squared Error: 1.2700111519874615
# R-squared: -0.2879181400018296

# %%
# prompt: Knn

import numpy as np
# Create and train the K-Nearest Neighbors Regressor model
# You can adjust parameters like n_neighbors (number of neighbors)
knn_regressor = KNeighborsRegressor(n_neighbors=5) # Using 5 neighbors as a default
knn_regressor.fit(X_train, y_train)

# Make predictions on the test data
y_pred_knn = knn_regressor.predict(X_test)

# Evaluate the KNN model
print('\nK-Nearest Neighbors (KNN) Model Evaluation:')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_knn))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_knn))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_knn)))
print('R-squared:', metrics.r2_score(y_test, y_pred_knn))
# Out:
# K-Nearest Neighbors (KNN) Model Evaluation:
# Mean Absolute Error: 0.8838044887780547
# Mean Squared Error: 1.3609647824438902
# Root Mean Squared Error: 1.1666039526951253
# R-squared: -0.08672605147468215

# %%
# prompt: XGboost

import numpy as np
# XGBoost Regressor model on PCA transformed data
xgb_regressor_pca = xgb.XGBRegressor(objective='reg:squarederror',
                                     n_estimators=100,
                                     learning_rate=0.1,
                                     max_depth=3,
                                     random_state=0)
xgb_regressor_pca.fit(X_train_pca, y_train)

# Make predictions on the PCA test data
y_pred_xgb_pca = xgb_regressor_pca.predict(X_test_pca)

# Evaluate the XGBoost model on PCA data
print('\nXGBoost Model Evaluation (after PCA):')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_xgb_pca))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_xgb_pca))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_xgb_pca)))
print('R-squared:', metrics.r2_score(y_test, y_pred_xgb_pca))

# Support Vector Regressor model on PCA transformed data
svm_regressor_pca = SVR(kernel='rbf')
svm_regressor_pca.fit(X_train_pca, y_train)

# Make predictions on the PCA test data
y_pred_svm_pca = svm_regressor_pca.predict(X_test_pca)

# Evaluate the SVM model on PCA data
print('\nSupport Vector Machine (SVM) Model Evaluation (after PCA):')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_svm_pca))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_svm_pca))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_svm_pca)))
print('R-squared:', metrics.r2_score(y_test, y_pred_svm_pca))
# Out:
# XGBoost Model Evaluation (after PCA):
# Mean Absolute Error: 0.8221074448202612
# Mean Squared Error: 1.230205118712739
# Root Mean Squared Error: 1.1091461214433105
# R-squared: 0.01768512425283497
#
# Support Vector Machine (SVM) Model Evaluation (after PCA):
# Mean Absolute Error: 0.7961401858259248
# Mean Squared Error: 1.1896449157165694
# Root Mean Squared Error: 1.0907084467063457
# R-squared: 0.05007231738055751

# %%
# prompt: Polynomials

import numpy as np
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# Apply Polynomial Features transformation
# degree=2 means including terms up to degree 2 (e.g., KH^2, KV^2, KH*KV)
poly = PolynomialFeatures(degree=2)
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)

# Get the feature names after polynomial transformation
poly_feature_names = poly.get_feature_names_out(input_features=x.columns)
print("\nPolynomial feature names:", poly_feature_names)

# Create and train the Linear Regression model on polynomial features
poly_regressor = LinearRegression()
poly_regressor.fit(X_train_poly, y_train)

# Make predictions on the polynomial test data
y_pred_poly = poly_regressor.predict(X_test_poly)

# Evaluate the Polynomial Regression model
print('\nPolynomial Regression Model Evaluation (Degree 2):')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_poly))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_poly))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_poly)))
print('R-squared:', metrics.r2_score(y_test, y_pred_poly))

# Optional: Apply OLS regression on the polynomial transformed data
# Add a constant (intercept) to the polynomial independent variables for statsmodels
X_train_poly_sm = sm.add_constant(X_train_poly)
X_test_poly_sm = sm.add_constant(X_test_poly)

# Create and fit the OLS model on polynomial data
ols_poly_model = sm.OLS(y_train, X_train_poly_sm)
ols_poly_results = ols_poly_model.fit()

# Print the summary of the OLS model on polynomial data
print(ols_poly_results.summary())

# Make predictions on the polynomial test data using the OLS model
y_pred_ols_poly = ols_poly_results.predict(X_test_poly_sm)

# Evaluate the OLS model on polynomial data
print('\nOLS Model Evaluation (after Polynomial Features - Degree 2):')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_ols_poly))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_ols_poly))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_ols_poly)))
print('R-squared:', metrics.r2_score(y_test, y_pred_ols_poly))
# Out:
# Polynomial feature names: ['1' 'KH' 'KV' 'KH^2' 'KH KV' 'KV^2']
#
# Polynomial Regression Model Evaluation (Degree 2):
# Mean Absolute Error: 0.8008764325052745
# Mean Squared Error: 1.1789107901109608
# Root Mean Squared Error: 1.08577658388407
# R-squared: 0.05864348254654306
#                             OLS Regression Results
# ...
# Dep. Variable:             AL(actual)   R-squared:                       0.055
# Model:                            OLS   Adj. R-squared:                  0.053
# Method:                 Least Squares   F-statistic:                     18.72
# Date:                Mon, 30 Jun 2025   Prob (F-statistic):           4.03e-18
# Time:                        02:05:27   Log-Likelihood:                -2603.6
# No. Observations:                1600   AIC:                             5219.
# Df Residuals:                    1594   BIC:                             5252.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...

# %%
# prompt: Polynomials on OLS

import numpy as np
# Add a constant (intercept) to the polynomial independent variables for statsmodels
X_train_poly_sm = sm.add_constant(X_train_poly)
X_test_poly_sm = sm.add_constant(X_test_poly)

# Create and fit the OLS model on polynomial data
ols_poly_model = sm.OLS(y_train, X_train_poly_sm)
ols_poly_results = ols_poly_model.fit()

# Print the summary of the OLS model on polynomial data
print(ols_poly_results.summary())

# Make predictions on the polynomial test data using the OLS model
y_pred_ols_poly = ols_poly_results.predict(X_test_poly_sm)

# Evaluate the OLS model on polynomial data
print('\nOLS Model Evaluation (after Polynomial Features - Degree 2):')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_ols_poly))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_ols_poly))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_ols_poly)))
print('R-squared:', metrics.r2_score(y_test, y_pred_ols_poly))
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             AL(actual)   R-squared:                       0.055
# Model:                            OLS   Adj. R-squared:                  0.053
# Method:                 Least Squares   F-statistic:                     18.72
# Date:                Mon, 30 Jun 2025   Prob (F-statistic):           4.03e-18
# Time:                        02:06:53   Log-Likelihood:                -2603.6
# No. Observations:                1600   AIC:                             5219.
# Df Residuals:                    1594   BIC:                             5252.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         33.7430     16.985      1.987      0.047       0.427      67.059
# ...

# %%
# prompt: Linear regression after polynomial

import numpy as np
# Create and train the Linear Regression model on polynomial features
poly_regressor = LinearRegression()
poly_regressor.fit(X_train_poly, y_train)

# Make predictions on the polynomial test data
y_pred_poly = poly_regressor.predict(X_test_poly)

# Evaluate the Polynomial Regression model
print('\nPolynomial Regression Model Evaluation (Degree 2):')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_poly))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_poly))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_poly)))
print('R-squared:', metrics.r2_score(y_test, y_pred_poly))
# Out:
# Polynomial Regression Model Evaluation (Degree 2):
# Mean Absolute Error: 0.8008764325052745
# Mean Squared Error: 1.1789107901109608
# Root Mean Squared Error: 1.08577658388407
# R-squared: 0.05864348254654306

# %%
# prompt: Knn after polynomials

import numpy as np
# K-Nearest Neighbors Regressor model on polynomial transformed data
knn_regressor_poly = KNeighborsRegressor(n_neighbors=5)
knn_regressor_poly.fit(X_train_poly, y_train)

# Make predictions on the polynomial test data
y_pred_knn_poly = knn_regressor_poly.predict(X_test_poly)

# Evaluate the KNN model on polynomial data
print('\nK-Nearest Neighbors (KNN) Model Evaluation (after Polynomial Features - Degree 2):')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_knn_poly))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_knn_poly))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_knn_poly)))
print('R-squared:', metrics.r2_score(y_test, y_pred_knn_poly))
# Out:
# K-Nearest Neighbors (KNN) Model Evaluation (after Polynomial Features - Degree 2):
# Mean Absolute Error: 0.8771660847880297
# Mean Squared Error: 1.3793492233416458
# Root Mean Squared Error: 1.174456990843703
# R-squared: -0.10140596907659938

# %%
# prompt: Random forest after polynomials

import numpy as np
# Apply Random Forest Regressor on the polynomial transformed data
rf_regressor_poly = RandomForestRegressor(n_estimators=100, random_state=0)
rf_regressor_poly.fit(X_train_poly, y_train)

# Make predictions on the polynomial test data
y_pred_rf_poly = rf_regressor_poly.predict(X_test_poly)

# Evaluate the Random Forest model on polynomial data
print('\nRandom Forest Model Evaluation (after Polynomial Features - Degree 2):')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_rf_poly))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_rf_poly))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_rf_poly)))
print('R-squared:', metrics.r2_score(y_test, y_pred_rf_poly))
# Out:
# Random Forest Model Evaluation (after Polynomial Features - Degree 2):
# Mean Absolute Error: 0.8860004164803177
# Mean Squared Error: 1.4405814200234437
# Root Mean Squared Error: 1.2002422338942433
# R-squared: -0.150299683433881

# %%
# prompt: Svm after polynomials

import numpy as np
# Support Vector Regressor model on polynomial transformed data
svm_regressor_poly = SVR(kernel='rbf') # Radial Basis Function kernel
svm_regressor_poly.fit(X_train_poly, y_train)

# Make predictions on the polynomial test data
y_pred_svm_poly = svm_regressor_poly.predict(X_test_poly)

# Evaluate the SVM model on polynomial data
print('\nSupport Vector Machine (SVM) Model Evaluation (after Polynomial Features - Degree 2):')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_svm_poly))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_svm_poly))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_svm_poly)))
print('R-squared:', metrics.r2_score(y_test, y_pred_svm_poly))
# Out:
# Support Vector Machine (SVM) Model Evaluation (after Polynomial Features - Degree 2):
# Mean Absolute Error: 0.7974494718090066
# Mean Squared Error: 1.1900848235757477
# Root Mean Squared Error: 1.0909100895929726
# R-squared: 0.04972105235372892

# %%
# prompt: XGboost after polynomials

import numpy as np
# XGBoost Regressor model on polynomial transformed data
xgb_regressor_poly = xgb.XGBRegressor(objective='reg:squarederror',
                                      n_estimators=100,
                                      learning_rate=0.1,
                                      max_depth=3,
                                      random_state=0)
xgb_regressor_poly.fit(X_train_poly, y_train)

# Make predictions on the polynomial test data
y_pred_xgb_poly = xgb_regressor_poly.predict(X_test_poly)

# Evaluate the XGBoost model on polynomial data
print('\nXGBoost Model Evaluation (after Polynomial Features - Degree 2):')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_xgb_poly))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_xgb_poly))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_xgb_poly)))
print('R-squared:', metrics.r2_score(y_test, y_pred_xgb_poly))

# Decision Tree Regressor model on polynomial transformed data
dt_regressor_poly = DecisionTreeRegressor(random_state=0)
dt_regressor_poly.fit(X_train_poly, y_train)

# Make predictions on the polynomial test data
y_pred_dt_poly = dt_regressor_poly.predict(X_test_poly)

# Evaluate the Decision Tree model on polynomial data
print('\nDecision Tree Model Evaluation (after Polynomial Features - Degree 2):')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_dt_poly))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_dt_poly))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_dt_poly)))
print('R-squared:', metrics.r2_score(y_test, y_pred_dt_poly))
# Out:
# XGBoost Model Evaluation (after Polynomial Features - Degree 2):
# Mean Absolute Error: 0.8268181319010822
# Mean Squared Error: 1.242663335306215
# Root Mean Squared Error: 1.114748103970675
# R-squared: 0.007737277914935503
#
# Decision Tree Model Evaluation (after Polynomial Features - Degree 2):
# Mean Absolute Error: 0.9651718422137412
# Mean Squared Error: 1.8002295386754157
# Root Mean Squared Error: 1.3417263277864886
# R-squared: -0.43747756264477755

# %%
# prompt: Hyper parametric tuning

import numpy as np
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR

# Define the parameter grid for SVR
# You can add other parameters like 'gamma' or 'epsilon' to the grid
param_grid_svr = {'C': [0.1, 1, 10, 100],
                  'kernel': ['linear', 'poly', 'rbf', 'sigmoid']} # Include polynomial kernel if applicable to your poly features

# Create the GridSearchCV object for SVR
grid_search_svr = GridSearchCV(SVR(), param_grid_svr, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)

# Fit the grid search to the training data
grid_search_svr.fit(X_train, y_train) # Use original features

# Print the best parameters found
print("\nBest parameters for SVR (Original Features):", grid_search_svr.best_params_)

# Print the best score found (negative mean squared error)
print("Best negative MSE for SVR (Original Features):", grid_search_svr.best_score_)

# Evaluate the best SVR model on the test data
best_svr = grid_search_svr.best_estimator_
y_pred_best_svr = best_svr.predict(X_test)

print('\nBest SVR Model Evaluation (Original Features):')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_best_svr))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_best_svr))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_best_svr)))
print('R-squared:', metrics.r2_score(y_test, y_pred_best_svr))


from sklearn.ensemble import RandomForestRegressor

# Define the parameter grid for RandomForestRegressor
param_grid_rf = {'n_estimators': [50, 100, 200],
                 'max_depth': [None, 10, 20, 30],
                 'min_samples_split': [2, 5, 10],
                 'min_samples_leaf': [1, 2, 4]}

# Create the GridSearchCV object for RandomForestRegressor
grid_search_rf = GridSearchCV(RandomForestRegressor(random_state=0), param_grid_rf, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)

# Fit the grid search to the training data
grid_search_rf.fit(X_train, y_train) # Use original features

# Print the best parameters found
print("\nBest parameters for Random Forest (Original Features):", grid_search_rf.best_params_)

# Print the best score found (negative mean squared error)
print("Best negative MSE for Random Forest (Original Features):", grid_search_rf.best_score_)

# Evaluate the best Random Forest model on the test data
best_rf = grid_search_rf.best_estimator_
y_pred_best_rf = best_rf.predict(X_test)

print('\nBest Random Forest Model Evaluation (Original Features):')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_best_rf))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_best_rf))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_best_rf)))
print('R-squared:', metrics.r2_score(y_test, y_pred_best_rf))


from sklearn.neighbors import KNeighborsRegressor

# Define the parameter grid for KNeighborsRegressor
param_grid_knn = {'n_neighbors': [3, 5, 7, 9],
                  'weights': ['uniform', 'distance'],
                  'metric': ['euclidean', 'manhattan', 'minkowski']}

# Create the GridSearchCV object for KNeighborsRegressor
grid_search_knn = GridSearchCV(KNeighborsRegressor(), param_grid_knn, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)

# Fit the grid search to the training data
grid_search_knn.fit(X_train, y_train) # Use original features

# Print the best parameters found
print("\nBest parameters for KNN (Original Features):", grid_search_knn.best_params_)

# Print the best score found (negative mean squared error)
print("Best negative MSE for KNN (Original Features):", grid_search_knn.best_score_)

# Evaluate the best KNN model on the test data
best_knn = grid_search_knn.best_estimator_
y_pred_best_knn = best_knn.predict(X_test)

print('\nBest KNN Model Evaluation (Original Features):')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_best_knn))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_best_knn))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_best_knn)))
print('R-squared:', metrics.r2_score(y_test, y_pred_best_knn))

from sklearn.tree import DecisionTreeRegressor

# Define the parameter grid for DecisionTreeRegressor
param_grid_dt = {'max_depth': [None, 10, 20, 30],
                 'min_samples_split': [2, 5, 10],
                 'min_samples_leaf': [1, 2, 4]}

# Create the GridSearchCV object for DecisionTreeRegressor
grid_search_dt = GridSearchCV(DecisionTreeRegressor(random_state=0), param_grid_dt, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)

# Fit the grid search to the training data
grid_search_dt.fit(X_train, y_train) # Use original features

# Print the best parameters found
print("\nBest parameters for Decision Tree (Original Features):", grid_search_dt.best_params_)

# Print the best score found (negative mean squared error)
print("Best negative MSE for Decision Tree (Original Features):", grid_search_dt.best_score_)

# Evaluate the best Decision Tree model on the test data
best_dt = grid_search_dt.best_estimator_
y_pred_best_dt = best_dt.predict(X_test)

print('\nBest Decision Tree Model Evaluation (Original Features):')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_best_dt))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_best_dt))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_best_dt)))
print('R-squared:', metrics.r2_score(y_test, y_pred_best_dt))


import xgboost as xgb

# Define the parameter grid for XGBoost Regressor
# This is a sample grid, you can expand it with more parameters
param_grid_xgb = {'n_estimators': [100, 200, 300],
                  'learning_rate': [0.01, 0.1, 0.2],
                  'max_depth': [3, 5, 7],
                  'subsample': [0.8, 1.0],
                  'colsample_bytree': [0.8, 1.0]}

# Create the GridSearchCV object for XGBoost Regressor
grid_search_xgb = GridSearchCV(xgb.XGBRegressor(objective='reg:squarederror', random_state=0),
                               param_grid_xgb,
                               cv=5,
                               scoring='neg_mean_squared_error',
                               n_jobs=-1)

# Fit the grid search to the training data
grid_search_xgb.fit(X_train, y_train) # Use original features

# Print the best parameters found
print("\nBest parameters for XGBoost (Original Features):", grid_search_xgb.best_params_)

# Print the best score found (negative mean squared error)
print("Best negative MSE for XGBoost (Original Features):", grid_search_xgb.best_score_)

# Evaluate the best XGBoost model on the test data
best_xgb = grid_search_xgb.best_estimator_
y_pred_best_xgb = best_xgb.predict(X_test)

print('\nBest XGBoost Model Evaluation (Original Features):')
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_best_xgb))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_best_xgb))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_best_xgb)))
print('R-squared:', metrics.r2_score(y_test, y_pred_best_xgb))
# Out:
# Best parameters for SVR (Original Features): {'C': 100, 'kernel': 'linear'}
# Best negative MSE for SVR (Original Features): -1.548260234827671
#
# Best SVR Model Evaluation (Original Features):
# Mean Absolute Error: 0.7971670369927131
# Mean Squared Error: 1.19128283052101
# Root Mean Squared Error: 1.0914590374911053
# R-squared: 0.0487644476171053
#
# Best parameters for Random Forest (Original Features): {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 100}
# Best negative MSE for Random Forest (Original Features): -1.6207171173497446
#
# Best Random Forest Model Evaluation (Original Features):
# Mean Absolute Error: 0.8255203212118211
# Mean Squared Error: 1.2389034265483168
# Root Mean Squared Error: 1.1130603876467424
# R-squared: 0.010739553103157995
#
# Best parameters for KNN (Original Features): {'metric': 'manhattan', 'n_neighbors': 9, 'weights': 'uniform'}
# Best negative MSE for KNN (Original Features): -1.7244000849768522
#
# ...

# %%
# prompt: Compare metrics

import pandas as pd
import numpy as np
# Function to evaluate a model and return the metrics
def evaluate_model(model, X_test, y_test, model_name):
  y_pred = model.predict(X_test)
  mae = metrics.mean_absolute_error(y_test, y_pred)
  mse = metrics.mean_squared_error(y_test, y_pred)
  rmse = np.sqrt(mse)
  r2 = metrics.r2_score(y_test, y_pred)

  return {
      'Model': model_name,
      'MAE': mae,
      'MSE': mse,
      'RMSE': rmse,
      'R-squared': r2
  }

# Store the evaluation metrics for each model in a list
evaluation_results = []

# Evaluate the base models (original features)
evaluation_results.append(evaluate_model(regressor, X_test, y_test, 'Linear Regression (Base)'))
evaluation_results.append(evaluate_model(rf_regressor, X_test, y_test, 'Random Forest (Base)'))
evaluation_results.append(evaluate_model(dt_regressor, X_test, y_test, 'Decision Tree (Base)'))
evaluation_results.append(evaluate_model(svm_regressor, X_test, y_test, 'SVM (Base)'))
evaluation_results.append(evaluate_model(knn_regressor, X_test, y_test, 'KNN (Base)'))
evaluation_results.append(evaluate_model(xgb_regressor, X_test, y_test, 'XGBoost (Base)'))
evaluation_results.append(evaluate_model(ols_results, X_test_sm, y_test, 'OLS (Base)')) # Note: OLS predicts on X_test_sm

# Evaluate models after PCA
evaluation_results.append(evaluate_model(lr_pca, X_test_pca, y_test, 'Linear Regression (PCA)'))
evaluation_results.append(evaluate_model(ols_pca_results, X_test_pca_sm, y_test, 'OLS (PCA)')) # Note: OLS predicts on X_test_pca_sm
evaluation_results.append(evaluate_model(rf_regressor_pca, X_test_pca, y_test, 'Random Forest (PCA)'))
evaluation_results.append(evaluate_model(knn_regressor_pca, X_test_pca, y_test, 'KNN (PCA)'))
evaluation_results.append(evaluate_model(dt_regressor_pca, X_test_pca, y_test, 'Decision Tree (PCA)'))
evaluation_results.append(evaluate_model(xgb_regressor_pca, X_test_pca, y_test, 'XGBoost (PCA)'))
evaluation_results.append(evaluate_model(svm_regressor_pca, X_test_pca, y_test, 'SVM (PCA)'))


# Evaluate models after Polynomial Features
evaluation_results.append(evaluate_model(poly_regressor, X_test_poly, y_test, 'Polynomial Regression (Degree 2)'))
evaluation_results.append(evaluate_model(ols_poly_results, X_test_poly_sm, y_test, 'OLS (Polynomial Degree 2)')) # Note: OLS predicts on X_test_poly_sm
evaluation_results.append(evaluate_model(knn_regressor_poly, X_test_poly, y_test, 'KNN (Polynomial Degree 2)'))
evaluation_results.append(evaluate_model(rf_regressor_poly, X_test_poly, y_test, 'Random Forest (Polynomial Degree 2)'))
evaluation_results.append(evaluate_model(svm_regressor_poly, X_test_poly, y_test, 'SVM (Polynomial Degree 2)'))
evaluation_results.append(evaluate_model(xgb_regressor_poly, X_test_poly, y_test, 'XGBoost (Polynomial Degree 2)'))
evaluation_results.append(evaluate_model(dt_regressor_poly, X_test_poly, y_test, 'Decision Tree (Polynomial Degree 2)'))

# Evaluate models after Hyperparameter Tuning (using best estimators)
evaluation_results.append(evaluate_model(best_svr, X_test, y_test, 'Tuned SVR (Original Features)'))
evaluation_results.append(evaluate_model(best_rf, X_test, y_test, 'Tuned Random Forest (Original Features)'))
evaluation_results.append(evaluate_model(best_knn, X_test, y_test, 'Tuned KNN (Original Features)'))
evaluation_results.append(evaluate_model(best_dt, X_test, y_test, 'Tuned Decision Tree (Original Features)'))
evaluation_results.append(evaluate_model(best_xgb, X_test, y_test, 'Tuned XGBoost (Original Features)'))


# Convert the list of dictionaries to a pandas DataFrame for easy comparison
metrics_df = pd.DataFrame(evaluation_results)

# Sort the DataFrame by a chosen metric (e.g., R-squared in descending order, or RMSE in ascending order)
# Here we'll sort by R-squared
metrics_df_sorted = metrics_df.sort_values(by='R-squared', ascending=False)

# Print the comparison table
print("\n\n--- Model Performance Comparison ---")
metrics_df_sorted

# Optional: Save the comparison table to a CSV file
# metrics_df_sorted.to_csv('model_comparison.csv', index=False)
# print("\nModel comparison saved to model_comparison.csv")
# Out:
# --- Model Performance Comparison ---
#                                       Model       MAE       MSE      RMSE  \
# 14         Polynomial Regression (Degree 2)  0.800876  1.178911  1.085777
# 15                OLS (Polynomial Degree 2)  0.800876  1.178911  1.085777
# 7                   Linear Regression (PCA)  0.802852  1.179339  1.085974
# 8                                 OLS (PCA)  0.802852  1.179339  1.085974
# 0                  Linear Regression (Base)  0.805584  1.181258  1.086857
# 6                                OLS (Base)  0.805584  1.181258  1.086857
# 13                                SVM (PCA)  0.796140  1.189645  1.090708
# 18                SVM (Polynomial Degree 2)  0.797449  1.190085  1.090910
# 3                                SVM (Base)  0.794756  1.190530  1.091114
# 21            Tuned SVR (Original Features)  0.797167  1.191283  1.091459
# 25        Tuned XGBoost (Original Features)  0.817659  1.206201  1.098272
# ...

# %%
# prompt: Any other

import matplotlib.pyplot as plt
import seaborn as sns

# Identify the best performing model based on R-squared
best_model_name = metrics_df_sorted.iloc[0]['Model']
print(f"\nBest performing model based on R-squared: {best_model_name}")

# Get the best estimator based on the identified model name
# This requires mapping the model name back to the corresponding estimator object
# We'll use a dictionary to map model names to the fitted estimators
model_estimators = {
    'Linear Regression (Base)': regressor,
    'Random Forest (Base)': rf_regressor,
    'Decision Tree (Base)': dt_regressor,
    'SVM (Base)': svm_regressor,
    'KNN (Base)': knn_regressor,
    'XGBoost (Base)': xgb_regressor,
    'OLS (Base)': ols_results, # Note: This is a statsmodels result object
    'Linear Regression (PCA)': lr_pca,
    'OLS (PCA)': ols_pca_results, # Note: This is a statsmodels result object
    'Random Forest (PCA)': rf_regressor_pca,
    'KNN (PCA)': knn_regressor_pca,
    'Decision Tree (PCA)': dt_regressor_pca,
    'XGBoost (PCA)': xgb_regressor_pca,
    'SVM (PCA)': svm_regressor_pca,
    'Polynomial Regression (Degree 2)': poly_regressor,
    'OLS (Polynomial Degree 2)': ols_poly_results, # Note: This is a statsmodels result object
    'KNN (Polynomial Degree 2)': knn_regressor_poly,
    'Random Forest (Polynomial Degree 2)': rf_regressor_poly,
    'SVM (Polynomial Degree 2)': svm_regressor_poly,
    'XGBoost (Polynomial Degree 2)': xgb_regressor_poly,
    'Decision Tree (Polynomial Degree 2)': dt_regressor_poly,
    'Tuned SVR (Original Features)': best_svr,
    'Tuned Random Forest (Original Features)': best_rf,
    'Tuned KNN (Original Features)': best_knn,
    'Tuned Decision Tree (Original Features)': best_dt,
    'Tuned XGBoost (Original Features)': best_xgb,
}

# Select the appropriate features for prediction based on the model name
# For OLS models from statsmodels, we need to use the version with the constant added
if 'OLS' in best_model_name:
    if 'PCA' in best_model_name:
      X_test_for_prediction = X_test_pca_sm
    elif 'Polynomial' in best_model_name:
      X_test_for_prediction = X_test_poly_sm
    else:
      X_test_for_prediction = X_test_sm
elif 'PCA' in best_model_name:
    X_test_for_prediction = X_test_pca
elif 'Polynomial' in best_model_name:
    X_test_for_prediction = X_test_poly
else:
    X_test_for_prediction = X_test

# Get the best performing model estimator
best_model_estimator = model_estimators[best_model_name]

# Make predictions using the best model
y_pred_best_model = best_model_estimator.predict(X_test_for_prediction)

# Create a scatter plot of Actual vs. Predicted values
plt.figure(figsize=(8, 6))
sns.scatterplot(x=y_test, y=y_pred_best_model)
plt.xlabel('Actual AL(actual)')
plt.ylabel(f'Predicted AL(actual) ({best_model_name})')
plt.title(f'Actual vs. Predicted AL(actual) ({best_model_name})')
plt.grid(True)

# Add a diagonal line for reference (where Actual = Predicted)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linestyle='--', linewidth=2)

plt.show()

# Optional: Plot the residuals (Difference between Actual and Predicted)
residuals = y_test - y_pred_best_model
plt.figure(figsize=(8, 6))
sns.scatterplot(x=y_pred_best_model, y=residuals)
plt.xlabel(f'Predicted AL(actual) ({best_model_name})')
plt.ylabel('Residuals (Actual - Predicted)')
plt.title(f'Residual Plot ({best_model_name})')
plt.axhline(y=0, color='red', linestyle='--', linewidth=2)
plt.grid(True)
plt.show()
# Out:
# Best performing model based on R-squared: Polynomial Regression (Degree 2)

# %%
# prompt: Any other

import matplotlib.pyplot as plt
def plot_predictions_and_residuals(y_true, y_pred, model_name):
  """
  Generates scatter plots of actual vs. predicted values and residuals.

  Args:
    y_true (pandas.Series or numpy.array): The actual target values.
    y_pred (numpy.array): The predicted values.
    model_name (str): The name of the model for plot titles.
  """
  # Create a scatter plot of Actual vs. Predicted values
  plt.figure(figsize=(8, 6))
  sns.scatterplot(x=y_true, y=y_pred)
  plt.xlabel('Actual AL(actual)')
  plt.ylabel(f'Predicted AL(actual) ({model_name})')
  plt.title(f'Actual vs. Predicted AL(actual) ({model_name})')
  plt.grid(True)

  # Add a diagonal line for reference (where Actual = Predicted)
  plt.plot([y_true.min(), y_true.max()], [y_true.min(), y_true.max()], color='red', linestyle='--', linewidth=2)

  plt.show()

  # Optional: Plot the residuals (Difference between Actual and Predicted)
  residuals = y_true - y_pred
  plt.figure(figsize=(8, 6))
  sns.scatterplot(x=y_pred, y=residuals)
  plt.xlabel(f'Predicted AL(actual) ({model_name})')
  plt.ylabel('Residuals (Actual - Predicted)')
  plt.title(f'Residual Plot ({model_name})')
  plt.axhline(y=0, color='red', linestyle='--', linewidth=2)
  plt.grid(True)
  plt.show()

# You can call this function for each model's predictions:

# Example for the base Linear Regression model:
plot_predictions_and_residuals(y_test, y_pred, 'Linear Regression (Base)')

# Example for the best tuned model (using the code you already have to identify the best model)
# Assuming you have already identified best_model_name and best_model_estimator, and X_test_for_prediction
# plot_predictions_and_residuals(y_test, y_pred_best_model, best_model_name)

# %%
# prompt: Conclusions

print("\n\n--- Conclusions ---")
print("Based on the model performance comparison (sorted by R-squared), the following conclusions can be drawn:")

# Identify the best model from the sorted DataFrame
best_model_row = metrics_df_sorted.iloc[0]
best_model_name_final = best_model_row['Model']
best_model_r2 = best_model_row['R-squared']
best_model_rmse = best_model_row['RMSE']

print(f"\nThe best performing model on the test set is the '{best_model_name_final}' with an R-squared of {best_model_r2:.4f}.")
print(f"This model explains approximately {best_model_r2*100:.2f}% of the variance in the target variable 'AL(actual)'.")
print(f"Its Root Mean Squared Error (RMSE) on the test set is {best_model_rmse:.4f}, indicating the typical magnitude of prediction errors in the units of 'AL(actual)'.")

print("\nObservations from the Model Performance Comparison Table:")
print("- Different models exhibit varying levels of performance, highlighting the importance of evaluating multiple algorithms.")
print("- Feature transformations (PCA and Polynomial Features) and hyperparameter tuning can sometimes improve model performance, although the degree of improvement varies depending on the dataset and the model.")
print("- The tuned models generally perform better than their base counterparts, indicating that hyperparameter optimization was effective.")
print("- It's crucial to consider both R-squared (goodness of fit) and error metrics (like MAE and RMSE) when comparing models.")

# You can add more specific conclusions based on the observed results in metrics_df_sorted
# For example:
# if 'Polynomial' in best_model_name_final:
#     print("- The use of polynomial features appears to be beneficial for this dataset and the best performing model.")
# if 'Tuned' in best_model_name_final:
#      print("- Hyperparameter tuning played a significant role in achieving the best performance.")

print("\nVisualizations (Actual vs. Predicted and Residual Plots) further confirm the performance of the best model:")
print("- The scatter plot of Actual vs. Predicted values for the '{best_model_name_final}' shows a strong linear relationship, indicating good predictions.")
print("- The residual plot for the '{best_model_name_final}' appears relatively random with no clear patterns, which is desirable for a good regression model. This suggests that the model captures most of the systematic information in the data.")

print("\nOverall, the analysis suggests that the '{best_model_name_final}' is the most suitable model among those tested for predicting 'AL(actual)' based on the 'KH' and 'KV' features in this dataset.")
print("Further steps could include exploring other potential features, trying different model architectures, or performing more extensive hyperparameter tuning.")
# Out:
# --- Conclusions ---
# Based on the model performance comparison (sorted by R-squared), the following conclusions can be drawn:
#
# The best performing model on the test set is the 'Polynomial Regression (Degree 2)' with an R-squared of 0.0586.
# This model explains approximately 5.86% of the variance in the target variable 'AL(actual)'.
# Its Root Mean Squared Error (RMSE) on the test set is 1.0858, indicating the typical magnitude of prediction errors in the units of 'AL(actual)'.
#
# Observations from the Model Performance Comparison Table:
# - Different models exhibit varying levels of performance, highlighting the importance of evaluating multiple algorithms.
# - Feature transformations (PCA and Polynomial Features) and hyperparameter tuning can sometimes improve model performance, although the degree of improvement varies depending on the dataset and the model.
# ...

# %%
# prompt: Conclusions

print("\n\n--- Conclusions ---")
print("Based on the comprehensive model evaluation and comparison:")

# Identify the best performing model based on the R-squared from the sorted DataFrame
if not metrics_df_sorted.empty:
    best_model_row = metrics_df_sorted.iloc[0]
    best_model_name_final = best_model_row['Model']
    best_model_r2 = best_model_row['R-squared']
    best_model_rmse = best_model_row['RMSE']
    best_model_mae = best_model_row['MAE']

    print(f"\nThe best performing model based on R-squared is the '{best_model_name_final}'.")
    print(f"Key metrics for the best model on the test set:")
    print(f"  - R-squared: {best_model_r2:.4f}")
    print(f"  - Root Mean Squared Error (RMSE): {best_model_rmse:.4f}")
    print(f"  - Mean Absolute Error (MAE): {best_model_mae:.4f}")


    print("\nInterpretation of the Best Model's Performance:")
    print(f"- The R-squared value of {best_model_r2:.4f} indicates that the '{best_model_name_final}' model explains approximately {best_model_r2*100:.2f}% of the variance in the 'AL(actual)' target variable based on the input features ('KH' and 'KV'). A higher R-squared is generally better, suggesting the model captures a significant portion of the relationship.")
    print(f"- The RMSE of {best_model_rmse:.4f} represents the standard deviation of the prediction errors. This means that, on average, the model's predictions are off by about {best_model_rmse:.4f} units of 'AL(actual)'. A lower RMSE indicates better prediction accuracy.")
    print(f"- The MAE of {best_model_mae:.4f} represents the average absolute difference between the predicted and actual values. This gives a straightforward measure of the average prediction error, where every error is weighted equally.")

    print("\nInsights from Feature Engineering and Hyperparameter Tuning:")
    print("- Comparing the 'Base' models to those with 'PCA' or 'Polynomial Features' and 'Tuned' versions provides insight into the benefits of feature engineering and optimization.")
    if 'Polynomial' in best_model_name_final:
        print("- The fact that the best model involves 'Polynomial Features' suggests that the relationship between the input features and the target variable is likely non-linear.")
    elif 'PCA' in best_model_name_final:
         print("- If a PCA model was the best, it would imply that the principal component captures the most important information for prediction and dimensionality reduction was beneficial.")
    if 'Tuned' in best_model_name_final:
         print("- The performance improvement observed in the 'Tuned' model compared to its base version confirms the importance of hyperparameter optimization for this dataset.")

    print("\nVisual Analysis:")
    print(f"- The scatter plot of Actual vs. Predicted values for the '{best_model_name_final}' visually confirms the model's performance. Points closely clustered around the red diagonal line (representing perfect predictions) indicate good accuracy.")
    print(f"- The residual plot for the '{best_model_name_final}' shows the distribution of errors. Ideally, residuals should be randomly scattered around zero with no discernible pattern (e.g., a cone shape or a curve). A random pattern suggests that the model's errors are not systematically biased.")


    print("\nOverall Summary:")
    print(f"Based on the evaluation metrics and visual analysis, the '{best_model_name_final}' model demonstrates the strongest performance among the tested approaches for predicting 'AL(actual)'. This model effectively captures the underlying patterns in the data, likely benefiting from {'polynomial feature engineering' if 'Polynomial' in best_model_name_final else ''}{' and ' if 'Polynomial' in best_model_name_final and 'Tuned' in best_model_name_final else ''}{'hyperparameter tuning' if 'Tuned' in best_model_name_final else ''}. While the results are promising, exploring additional features or more advanced modeling techniques could potentially yield further improvements.")

else:
    print("No evaluation results available to draw conclusions.")
# Out:
# --- Conclusions ---
# Based on the comprehensive model evaluation and comparison:
#
# The best performing model based on R-squared is the 'Polynomial Regression (Degree 2)'.
# Key metrics for the best model on the test set:
#   - R-squared: 0.0586
#   - Root Mean Squared Error (RMSE): 1.0858
#   - Mean Absolute Error (MAE): 0.8009
#
# Interpretation of the Best Model's Performance:
# - The R-squared value of 0.0586 indicates that the 'Polynomial Regression (Degree 2)' model explains approximately 5.86% of the variance in the 'AL(actual)' target variable based on the input features ('KH' and 'KV'). A higher R-squared is generally better, suggesting the model captures a significant portion of the relationship.
# - The RMSE of 1.0858 represents the standard deviation of the prediction errors. This means that, on average, the model's predictions are off by about 1.0858 units of 'AL(actual)'. A lower RMSE indicates better prediction accuracy.
# ...

# %%
# prompt: Conclusions

# Print the comparison table
print("\n\n--- Model Performance Comparison ---")
display(metrics_df_sorted) # Use display for better formatting in Colab/Jupyter

# Identify the best performing model based on R-squared
if not metrics_df_sorted.empty:
    best_model_row = metrics_df_sorted.iloc[0]
    best_model_name_final = best_model_row['Model']
    best_model_r2 = best_model_row['R-squared']
    best_model_rmse = best_model_row['RMSE']
    best_model_mae = best_model_row['MAE']

    print("\n\n--- Conclusions ---")
    print("Based on the comprehensive model evaluation and comparison:")
    print(f"\nThe best performing model based on R-squared is the '{best_model_name_final}'.")
    print(f"Key metrics for the best model on the test set:")
    print(f"  - R-squared: {best_model_r2:.4f}")
    print(f"  - Root Mean Squared Error (RMSE): {best_model_rmse:.4f}")
    print(f"  - Mean Absolute Error (MAE): {best_model_mae:.4f}")


    print("\nInterpretation of the Best Model's Performance:")
    print(f"- The R-squared value of {best_model_r2:.4f} indicates that the '{best_model_name_final}' model explains approximately {best_model_r2*100:.2f}% of the variance in the 'AL(actual)' target variable based on the input features ('KH' and 'KV'). A higher R-squared is generally better, suggesting the model captures a significant portion of the relationship.")
    print(f"- The RMSE of {best_model_rmse:.4f} represents the standard deviation of the prediction errors. This means that, on average, the model's predictions are off by about {best_model_rmse:.4f} units of 'AL(actual)'. A lower RMSE indicates better prediction accuracy.")
    print(f"- The MAE of {best_model_mae:.4f} represents the average absolute difference between the predicted and actual values. This gives a straightforward measure of the average prediction error, where every error is weighted equally.")

    print("\nInsights from Feature Engineering and Hyperparameter Tuning:")
    print("- Comparing the 'Base' models to those with 'PCA' or 'Polynomial Features' and 'Tuned' versions provides insight into the benefits of feature engineering and optimization.")
    if 'Polynomial' in best_model_name_final:
        print("- The fact that the best model involves 'Polynomial Features' suggests that the relationship between the input features and the target variable is likely non-linear.")
    elif 'PCA' in best_model_name_final:
         print("- If a PCA model was the best, it would imply that the principal component captures the most important information for prediction and dimensionality reduction was beneficial.")
    if 'Tuned' in best_model_name_final:
         print("- The performance improvement observed in the 'Tuned' model compared to its base version confirms the importance of hyperparameter optimization for this dataset.")

    print("\nVisual Analysis:")
    # We assume the plots for the best model are already generated or will be generated after this conclusion section.
    print(f"- The scatter plot of Actual vs. Predicted values for the '{best_model_name_final}' visually confirms the model's performance. Points closely clustered around the red diagonal line (representing perfect predictions) indicate good accuracy.")
    print(f"- The residual plot for the '{best_model_name_final}' shows the distribution of errors. Ideally, residuals should be randomly scattered around zero with no discernible pattern (e.g., a cone shape or a curve). A random pattern suggests that the model's errors are not systematically biased.")


    print("\nOverall Summary:")
    print(f"Based on the evaluation metrics and visual analysis, the '{best_model_name_final}' model demonstrates the strongest performance among the tested approaches for predicting 'AL(actual)'. This model effectively captures the underlying patterns in the data, likely benefiting from {'polynomial feature engineering' if 'Polynomial' in best_model_name_final else ''}{' and ' if 'Polynomial' in best_model_name_final and 'Tuned' in best_model_name_final else ''}{'hyperparameter tuning' if 'Tuned' in best_model_name_final else ''}. While the results are promising, exploring additional features or more advanced modeling techniques could potentially yield further improvements.")

else:
    print("\n\n--- Conclusions ---")
    print("No evaluation results available to draw conclusions.")
# Out:
# --- Model Performance Comparison ---
#                                       Model       MAE       MSE      RMSE  \
# 14         Polynomial Regression (Degree 2)  0.800876  1.178911  1.085777
# 15                OLS (Polynomial Degree 2)  0.800876  1.178911  1.085777
# 7                   Linear Regression (PCA)  0.802852  1.179339  1.085974
# 8                                 OLS (PCA)  0.802852  1.179339  1.085974
# 0                  Linear Regression (Base)  0.805584  1.181258  1.086857
# 6                                OLS (Base)  0.805584  1.181258  1.086857
# 13                                SVM (PCA)  0.796140  1.189645  1.090708
# 18                SVM (Polynomial Degree 2)  0.797449  1.190085  1.090910
# 3                                SVM (Base)  0.794756  1.190530  1.091114
# 21            Tuned SVR (Original Features)  0.797167  1.191283  1.091459
# 25        Tuned XGBoost (Original Features)  0.817659  1.206201  1.098272
# ...
