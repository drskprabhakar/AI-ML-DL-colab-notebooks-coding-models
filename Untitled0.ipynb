# %% [markdown]
# <a href="https://colab.research.google.com/github/drskprabhakar/Axial-Length-Prediction-ML-Regression-mode/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel('/content/drive/MyDrive/diabetes copy.xlsx')

# %%
data.shape
# Out:
# (768, 9)

# %%
data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
sns.heatmap(data)
# Out:
# <Axes: >

# %%
df = pd.DataFrame(data)
df.drop(columns=['Pregnancies', 'SkinThickness', 'Insulin', 'DiabetesPedigreeFunction'], inplace=True)
df.shape
# Out:
# (768, 5)

# %%
df.head()
# Out:
#    Glucose  BloodPressure   BMI  Age  Outcome
# 0      148             72  33.6   50        1
# 1       85             66  26.6   31        0
# 2      183             64  23.3   32        1
# 3       89             66  28.1   21        0
# 4      137             40  43.1   33        1

# %%
df.isnull().sum()
# Out:
# Glucose          0
# BloodPressure    0
# BMI              0
# Age              0
# Outcome          0
# dtype: int64

# %%
df.corr()
# Out:
#                 Glucose  BloodPressure       BMI       Age   Outcome
# Glucose        1.000000       0.152590  0.221071  0.263514  0.466581
# BloodPressure  0.152590       1.000000  0.281805  0.239528  0.065068
# BMI            0.221071       0.281805  1.000000  0.036242  0.292695
# Age            0.263514       0.239528  0.036242  1.000000  0.238356
# Outcome        0.466581       0.065068  0.292695  0.238356  1.000000

# %%
sns.heatmap(df)
# Out:
# <Axes: >

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.pairplot(df)

# %%
sns.displot(df)

# %%
sns.histplot(df)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
x = df.drop(['Outcome'], axis=1).values
y = df['Outcome'].values

# %%
from sklearn.model_selection import train_test_split
x_train, y_train, x_test, y_test = train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x, y)
# Out:
# LogisticRegression()

# %%
y_predl=model.predict(x)
model.score(x,y)
# Out:
# 0.7734375

# %%
from sklearn.metrics import confusion_matrix, classification_report
confusion_matrix(y, y_predl)
# Out:
# array([[439,  61],
#        [113, 155]])

# %%
print(classification_report(y, y_predl))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.88      0.83       500
#            1       0.72      0.58      0.64       268
#
#     accuracy                           0.77       768
#    macro avg       0.76      0.73      0.74       768
# weighted avg       0.77      0.77      0.77       768

# %%
from sklearn.svm import SVC
models= SVC()
models.fit(x,y)
# Out:
# SVC()

# %%
y_preds=models.predict(x)
models.score(x,y)
# Out:
# 0.7721354166666666

# %%
from sklearn.tree import DecisionTreeClassifier
modelt = DecisionTreeClassifier()
modelt.fit(x,y)
# Out:
# DecisionTreeClassifier()

# %%
y_predt = modelt.predict(x)
modelt.score(x,y)
# Out:
# 1.0

# %%
from sklearn.ensemble import RandomForestClassifier
modelr = RandomForestClassifier()
modelr.fit(x,y)
# Out:
# RandomForestClassifier()

# %%
y_predr=modelr.predict(x)
modelr.score(x,y)
# Out:
# 1.0

# %%
confusion_matrix(y, y_predr)
# Out:
# array([[500,   0],
#        [  0, 268]])

# %%
print(classification_report(y, y_predr))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       500
#            1       1.00      1.00      1.00       268
#
#     accuracy                           1.00       768
#    macro avg       1.00      1.00      1.00       768
# weighted avg       1.00      1.00      1.00       768

# %%
df.head()
# Out:
#    Glucose  BloodPressure   BMI  Age  Outcome
# 0      148             72  33.6   50        1
# 1       85             66  26.6   31        0
# 2      183             64  23.3   32        1
# 3       89             66  28.1   21        0
# 4      137             40  43.1   33        1

# %%
modelr.predict([[148,	72,	33.6,	50]])
# Out:
# array([1])

# %%
modelr.predict([[89,	66,	28.1,	21]])
# Out:
# array([0])
