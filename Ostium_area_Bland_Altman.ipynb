# %% [markdown]
# <a href="https://colab.research.google.com/github/drskprabhakar/AI-ML-DL-colab-notebooks-coding-models/blob/main/Ostium_area_Bland_Altman.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_excel('/content/drive/MyDrive/DCR Ostium area.xlsx')

# %%
df.shape
# Out:
# (25, 2)

# %%
df.columns
# Out:
# Index(['Data 1', 'Data 2'], dtype='object')

# %%
df.mean()
# Out:
# Data 1    78.916576
# Data 2    58.957600
# dtype: float64

# %%
# prompt: Bland Altman plots

import matplotlib.pyplot as plt
# !pip install statsmodels

import statsmodels.api as sm

# Assuming 'variable1' and 'variable2' are the columns you want to compare
f, ax = plt.subplots(1, figsize =(8,5))
sm.graphics.mean_diff_plot(df['Data 1'], df['Data 2'], ax = ax)
plt.show()

# %%
# prompt: Bland Altman plots

# !pip install statsmodels

import statsmodels.api as sm
import matplotlib.pyplot as plt

# Assuming 'Method 1' and 'Method 2' are the column names for your measurements
# Replace with actual column names if different
method1 = df['Data 1']
method2 = df['Data 2']

# Calculate the difference and mean
difference = method1 - method2
mean = (method1 + method2) / 2

# Perform Bland-Altman analysis
f, ax = plt.subplots(1, figsize =(8,5))
sm.graphics.mean_diff_plot(method1, method2, ax = ax)
plt.show()
