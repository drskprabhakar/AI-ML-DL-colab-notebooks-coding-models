# %% [markdown]
# <a href="https://colab.research.google.com/github/drskprabhakar/AI-ML-DL-colab-notebooks-coding-models/blob/main/FDDT_roc_curve_1day_1_month_3month.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: Auc

import matplotlib.pyplot as plt
from sklearn.metrics import auc

# Given values
thresholds = [0.0, 0.25, 0.5, 0.75, 1.0]
TP = [25, 22, 18, 10, 0]
FP = [25, 9, 5, 2, 0]
TN = [0, 16, 20, 23, 25]
FN = [0, 3, 7, 15, 25]

# Calculate TPR and FPR
TPR = [tp / (tp + fn) if (tp+fn) else 0 for tp, fn in zip(TP, FN)]
FPR = [fp / (fp + tn) if (fp+tn) else 0 for fp, tn in zip(FP, TN)]

# Calculate AUC
roc_auc = auc(FPR, TPR)
print("AUC:", roc_auc)

# Plot ROC curve
plt.figure()
plt.plot(FPR, TPR, marker='o', color='orange', label='ROC Curve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Random Classifier')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve for postop day1 FDDT test')
plt.legend()
plt.show()
# Out:
# AUC: 0.8128000000000001

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import auc

# Values for Model 2 at a specific threshold (provided)
TP = 21
FP = 1
TN = 1
FN = 2

# Calculate TPR and FPR for Model 1
#TPR1 = TP1 / (TP1 + FN1)  # True Positive Rate for Model 1
#FPR1 = FP1 / (FP1 + TN1)  # False Positive Rate for Model 1

# Calculate TPR and FPR for Model 2
TPR = TP / (TP + FN)  # True Positive Rate for Model 2
FPR = FP / (FP + TN)  # False Positive Rate for Model 2


# Plot ROC curves
plt.figure()
#plt.plot([0, FPR1, 1], [0, TPR1, 1], marker='o', color='blue', label='Model 1 ROC Curve')
plt.plot([0, FPR, 1], [0, TPR, 1], marker='o', color='green', label='ROC Curve')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Logistic Classifier')
#plt.scatter(FPR1, TPR1, color='red')  # Highlight the point for Model 1
plt.scatter(FPR, TPR, color='purple')  # Highlight the point for Model 2
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves')
plt.legend()
plt.show()

# %%
# prompt: Auc

# Calculate AUC for Model 2
roc_auc = auc([0, FPR, 1], [0, TPR, 1])
print("Area under the ROC curve: {:.2f}".format(roc_auc))
# Out:
# Area under the ROC curve: 0.71

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import auc

# Values for Model 1 at a specific threshold (example)

# Values for Model 2 at a specific threshold (provided)
TP = 21
FP = 1
TN = 1
FN = 2

# Calculate TPR and FPR for Model 1
#TPR1 = TP1 / (TP1 + FN1)  # True Positive Rate for Model 1
#FPR1 = FP1 / (FP1 + TN1)  # False Positive Rate for Model 1

# Calculate TPR and FPR for Model 2
TPR = TP / (TP + FN)  # True Positive Rate for Model 2
FPR = FP / (FP + TN)  # False Positive Rate for Model 2

# Plot ROC curves
plt.figure()
#plt.plot([0, FPR1, 1], [0, TPR1, 1], marker='o', color='blue', label='Model 1 ROC Curve')
plt.plot([0, FPR, 1], [0, TPR, 1], marker='o', color='green', label='ROC Curve')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Logistic Classifier')
#plt.scatter(FPR1, TPR1, color='red')  # Highlight the point for Model 1
plt.scatter(FPR, TPR, color='purple')  # Highlight the point for Model 2
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves')
plt.legend()
plt.show()

# %%
# prompt: Auc

# Calculate AUC for Model 2
roc_auc = auc([0, FPR, 1], [0, TPR, 1])
print("Area under the ROC curve: {:.2f}".format(roc_auc))
# Out:
# Area under the ROC curve: 0.71

# %%
import matplotlib.pyplot as plt

# Given values at threshold 0.2
TP = 23
FP = 0
TN =2
FN = 0

# Calculate TPR and FPR
TPR = TP / (TP + FN)  # True Positive Rate
FPR = FP / (FP + TN)  # False Positive Rate

# Plot ROC curve for threshold 0.5
plt.figure()
plt.plot([0, FPR, 1], [0, TPR, 1], marker='o', color='orange', label='Ext DCR ROC Curve (1 month and 3 month)')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Random Classifier (threshold=0.5)')
plt.scatter(FPR, TPR, color='red')  # Highlight the point for threshold 0.5
plt.text(FPR, TPR, '(0.5)', fontsize=12, verticalalignment='bottom', horizontalalignment='right')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for FDDT (AUC=1.00)')
plt.legend()
plt.show()
roc_auc = auc([0, FPR, 1], [0, TPR, 1])
print("Area under the ROC curve: {:.2f}".format(roc_auc))
# Out:
# Area under the ROC curve: 1.00

# %%
import matplotlib.pyplot as plt

# Given values at threshold 0.2
TP = 23
FP = 21
TN = 4
FN = 2

# Calculate TPR and FPR
TPR = TP / (TP + FN)  # True Positive Rate
FPR = FP / (FP + TN)  # False Positive Rate

# Plot ROC curve for threshold 0.5
plt.figure()
plt.plot([0, FPR, 1], [0, TPR, 1], marker='o', color='orange', label='ROC Curve (Threshold = 0.5)')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Random Classifier')
plt.scatter(FPR, TPR, color='red')  # Highlight the point for threshold 0.5
plt.text(FPR, TPR, '(0.2)', fontsize=12, verticalalignment='bottom', horizontalalignment='right')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for postop 1month FDDT test')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Given values at threshold 0.5
TP = 23
FP = 20
TN = 5
FN = 2

# Calculate TPR and FPR
TPR = TP / (TP + FN)  # True Positive Rate
FPR = FP / (FP + TN)  # False Positive Rate

# Plot ROC curve for threshold 0.5
plt.figure()
plt.plot([0, FPR, 1], [0, TPR, 1], marker='o', color='orange', label='ROC Curve (Threshold = 0.5)')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Random Classifier')
plt.scatter(FPR, TPR, color='red')  # Highlight the point for threshold 0.5
plt.text(FPR, TPR, '(1)', fontsize=12, verticalalignment='bottom', horizontalalignment='right')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for postop 3months FDDT test')
plt.legend()
plt.show()

# %%
# prompt: Auc

# Calculate AUC for the ROC curve at threshold 0.5
roc_auc = auc([0, FPR, 1], [0, TPR, 1])
print("Area under the ROC curve (Threshold 0.5): {:.2f}".format(roc_auc))
# Out:
# Area under the ROC curve (Threshold 0.5): 0.56

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import auc

# Values for Model 1 at a specific threshold (example)
TP1 = 22
FP1 = 9
TN1 = 16
FN1 = 3

# Values for Model 2 at a specific threshold (provided)
TP2 = 23
FP2 = 21
TN2 = 4
FN2 = 2

# Calculate TPR and FPR for Model 1
TPR1 = TP1 / (TP1 + FN1)  # True Positive Rate for Model 1
FPR1 = FP1 / (FP1 + TN1)  # False Positive Rate for Model 1

# Calculate TPR and FPR for Model 2
TPR2 = TP2 / (TP2 + FN2)  # True Positive Rate for Model 2
FPR2 = FP2 / (FP2 + TN2)  # False Positive Rate for Model 2

# Plot ROC curves
plt.figure()
plt.plot([0, FPR1, 1], [0, TPR1, 1], marker='o', color='blue', label='Model 1 ROC Curve')
plt.plot([0, FPR2, 1], [0, TPR2, 1], marker='o', color='green', label='Model 2 ROC Curve')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Random Classifier')
plt.scatter(FPR1, TPR1, color='red')  # Highlight the point for Model 1
plt.scatter(FPR2, TPR2, color='purple')  # Highlight the point for Model 2
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Comparison of ROC Curves')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import auc

# Values for Model 1 at a specific threshold (example)
TP1 = 22
FP1 = 9
TN1 = 16
FN1 = 3

# Values for Model 2 at a specific threshold (provided)
TP2 = 23
FP2 = 21
TN2 = 4
FN2 = 2

# model3
TP3 = 23
FP3 = 20
TN3 = 5
FN3 = 2

# Calculate TPR and FPR for Model 1
TPR1 = TP1 / (TP1 + FN1)  # True Positive Rate for Model 1
FPR1 = FP1 / (FP1 + TN1)  # False Positive Rate for Model 1

# Calculate TPR and FPR for Model 2
TPR2 = TP2 / (TP2 + FN2)  # True Positive Rate for Model 2
FPR2 = FP2 / (FP2 + TN2)  # False Positive Rate for Model 2

# model 3
TPR3 = TP3/(TP3+FN3)
FPR3 = FP3/(FP3+TN3)

# Plot ROC curves
plt.figure()
plt.plot([0, FPR1, 1], [0, TPR1, 1], marker='o', color='blue', label='Postop day1 FDDT ROC Curve(auc=0.81)')
plt.plot([0, FPR2, 1], [0, TPR2, 1], marker='o', color='green', label='Postop 1month FDDT ROC Curve(auc=0.54)')
plt.plot([0, FPR3, 1], [0, TPR3, 1], marker='o', color='red', label='Postop 3months FDDT ROC curve(auc=0.56)')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Random Classifier (Threshold=0.5)')
plt.scatter(FPR1, TPR1, color='red')  # Highlight the point for Model 1
plt.scatter(FPR2, TPR2, color='purple')  # Highlight the point for Model 2
plt.scatter(FPR3, TPR3, color='orange')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Comparison of ROC Curves for FDDT')
plt.legend()
plt.show()

# %%
# prompt: Auc

# Values for Model 1 at a specific threshold (example)
TP1 = 22
FP1 = 9
TN1 = 16
FN1 = 3

# Values for Model 2 at a specific threshold (provided)
TP2 = 23
FP2 = 21
TN2 = 4
FN2 = 2

# model3
TP3 = 23
FP3 = 20
TN3 = 5
FN3 = 2

# Calculate TPR and FPR for Model 1
TPR1 = TP1 / (TP1 + FN1)  # True Positive Rate for Model 1
FPR1 = FP1 / (FP1 + TN1)  # False Positive Rate for Model 1

# Calculate TPR and FPR for Model 2
TPR2 = TP2 / (TP2 + FN2)  # True Positive Rate for Model 2
FPR2 = FP2 / (FP2 + TN2)  # False Positive Rate for Model 2

# model 3
TPR3 = TP3/(TP3+FN3)
FPR3 = FP3/(FP3+TN3)

# Calculate AUC for each model
auc1 = auc([0, FPR1, 1], [0, TPR1, 1])
auc2 = auc([0, FPR2, 1], [0, TPR2, 1])
auc3 = auc([0, FPR3, 1], [0, TPR3, 1])

print("AUC for Model 1 (Postop day1 FDDT test): {:.2f}".format(auc1))
print("AUC for Model 2 (Postop 1month FDDT test): {:.2f}".format(auc2))
print("AUC for Model 3 (Postop 3months FDDT test): {:.2f}".format(auc3))
# Out:
# AUC for Model 1 (Postop day1 FDDT test): 0.76
# AUC for Model 2 (Postop 1month FDDT test): 0.54
# AUC for Model 3 (Postop 3months FDDT test): 0.56

# %%
# prompt: roc curve for 2 modules with code for auc

import matplotlib.pyplot as plt
# Values for Model 1 at a specific threshold (example)
TP1 = 21
FP1 = 1
TN1 = 1
FN1 = 2

# Values for Model 2 at a specific threshold (provided)
TP2 = 6
FP2 = 3
TN2 = 1
FN2 = 15

# Calculate TPR and FPR for Model 1
TPR1 = TP1 / (TP1 + FN1)  # True Positive Rate for Model 1
FPR1 = FP1 / (FP1 + TN1)  # False Positive Rate for Model 1

# Calculate TPR and FPR for Model 2
TPR2 = TP2 / (TP2 + FN2)  # True Positive Rate for Model 2
FPR2 = FP2 / (FP2 + TN2)  # False Positive Rate for Model 2

# Plot ROC curves
plt.figure()
plt.plot([0, FPR1, 1], [0, TPR1, 1], marker='o', color='blue', label='External DCR ROC Curve (AUC=0.71)')
plt.plot([0, FPR2, 1], [0, TPR2, 1], marker='o', color='green', label='Endo-nasal DCR ROC Curve (AUC=0.27)')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Random Classifier (Threshold=0.5)')
plt.scatter(FPR1, TPR1, color='red')  # Highlight the point for Model 1
plt.scatter(FPR2, TPR2, color='purple')  # Highlight the point for Model 2
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Comparison of ROC Curves for FDDT (day 1 and 1 month)')
plt.legend()
plt.show()

# Calculate AUC for each model
auc1 = auc([0, FPR1, 1], [0, TPR1, 1])
auc2 = auc([0, FPR2, 1], [0, TPR2, 1])

print("AUC for Model 1: {:.2f}".format(auc1))
print("AUC for Model 2: {:.2f}".format(auc2))
# Out:
# AUC for Model 1: 0.71
# AUC for Model 2: 0.27

# %%
# prompt: roc curve for 2 modules with code for auc

import matplotlib.pyplot as plt
# Values for Model 1 at a specific threshold (example)
TP1 = 23
FP1 = 0
TN1 = 2
FN1 = 0

# Values for Model 2 at a specific threshold (provided)
TP2 = 20
FP2 = 1
TN2 = 4
FN2 = 0

# Calculate TPR and FPR for Model 1
TPR1 = TP1 / (TP1 + FN1)  # True Positive Rate for Model 1
FPR1 = FP1 / (FP1 + TN1)  # False Positive Rate for Model 1

# Calculate TPR and FPR for Model 2
TPR2 = TP2 / (TP2 + FN2)  # True Positive Rate for Model 2
FPR2 = FP2 / (FP2 + TN2)  # False Positive Rate for Model 2

# Plot ROC curves
plt.figure()
plt.plot([0, FPR1, 1], [0, TPR1, 1], marker='o', color='blue', label='External DCR ROC Curve (AUC=1.00)')
plt.plot([0, FPR2, 1], [0, TPR2, 1], marker='o', color='green', label='Endo-nasal DCR ROC Curve (AUC=0.90)')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Random Classifier (Threshold=0.5)')
plt.scatter(FPR1, TPR1, color='red')  # Highlight the point for Model 1
plt.scatter(FPR2, TPR2, color='purple')  # Highlight the point for Model 2
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Comparison of ROC Curves for FDDT (1 month and 3 months)')
plt.legend()
plt.show()

# Calculate AUC for each model
auc1 = auc([0, FPR1, 1], [0, TPR1, 1])
auc2 = auc([0, FPR2, 1], [0, TPR2, 1])

print("AUC for Model 1: {:.2f}".format(auc1))
print("AUC for Model 2: {:.2f}".format(auc2))
# Out:
# AUC for Model 1: 1.00
# AUC for Model 2: 0.90
